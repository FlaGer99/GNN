# %%
import json
import pickle
import urllib
import numpy as np
import torch
#import torch_geometric_temporal
#from torch_geometric_temporal.signal import StaticGraphTemporalSignal
#from sklearn.preprocessing import StandardScaler
import time

#torch.set_default_device('cuda:0')

# %%
import torch.nn.functional as F
from matplotlib import pyplot as plt
#from torch_geometric_temporal.nn.recurrent import DCRNN
#from torch_geometric_temporal.signal import temporal_signal_split

#train_dataset, test_dataset = temporal_signal_split(dataset, train_ratio=0.8)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

data = pd.read_csv(r"data/prices.csv")

columns = [data.iloc[:, i].to_numpy() for i in range(1,len(data.columns))]
series = list(map(list, zip(*columns)))

# Normalization of the data
scaler = StandardScaler()
series = scaler.fit_transform(series)

len(series)
#series[0]
# Out:
# 8030

# %%
mu = scaler.mean_
sigma = scaler.scale_
sigma
# Out:
# array([ 33.81230562,  29.92566225,  23.95642845,  23.08344885,
#         24.99149734,  30.37790109,  64.62803107,  75.02307404,
#         86.47102203,  99.48511891, 119.52592161, 135.64488764,
#        134.60637697, 142.45167965, 145.43296655, 147.49190841,
#        161.93358766, 181.04869188, 142.53849513, 122.44785276,
#        105.25500325,  93.67965756,  52.06614424,  47.67590622])

# %%
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

lags = 3
X, y = create_sequences(series, lags)
#X[1]

# %%
# lags = 3
# dataset = [list(series[i]) + list(series[i+1]) for i in range(0, len(series)-2)]
# for j in range(2, lags):
#     dataset = [dataset[i] + list(series[i+j]) for i in range(0, len(series)-j-1)]
#     #print(j)
# len(dataset)

# %%
# max_hourly = np.max(np.array(series), axis=0)/20
# max_hourly

# %%
lag_gnn = 90
train_size = int(0.8 * (len(X)-lag_gnn+1))
train_size
# Out:
# 6350

# %%
train_stop = train_size+lag_gnn-1
train_stop
# Out:
# 6439

# %%
test_size = len(X)-train_size-lag_gnn+1
test_size
# Out:
# 1588

# %%
X_train = X[lag_gnn-1:train_stop]
X_test = X[train_stop:]
X_test[0]*sigma+mu
# Out:
# array([[18.4 , 18.39, 18.35, 18.39, 18.39, 18.39, 18.39, 17.74, 18.45,
#         21.16, 27.1 , 18.37, 18.8 , 19.32, 19.32, 19.87, 19.61, 18.51,
#         18.37, 18.5 , 18.5 , 18.45, 17.42, 15.37],
#        [14.05, 14.18, 14.89, 15.33, 14.02, 15.38, 15.39, 13.78, 14.06,
#         18.22, 18.28, 18.38, 18.39, 18.48, 18.42, 18.39, 18.39, 18.36,
#         18.21, 17.68, 18.11, 17.37, 15.39, 15.31],
#        [15.38, 15.4 , 16.14, 18.28, 18.28, 18.3 , 18.44, 18.38, 18.96,
#         19.35, 18.36, 20.29, 19.89, 20.2 , 20.42, 20.43, 20.43, 19.02,
#         18.45, 19.04, 18.47, 22.98, 20.91, 18.87]])

# %%
y_train = y[lag_gnn-1:train_stop]
y_test = y[train_stop:]
len(y_test)
# Out:
# 1588

# %%
class FFNetwork(torch.nn.Module):
    def __init__(self, node_features):
        super(FFNetwork, self).__init__()
        self.linear1 = torch.nn.Linear(node_features*24, 20)
        #self.linear2 = torch.nn.Linear(50, 50)
        self.linear3 = torch.nn.Linear(20, 24)
        #self.dropout1 = torch.nn.Dropout(0.3)
        #self.dropout2 = torch.nn.Dropout(0.15)

    def forward(self, x):
        h = self.linear1(x)
        h = F.relu(h)
        #h = self.linear2(h)
        #h = self.dropout2(h)
        h = self.linear3(h)
        #h = self.dropout1(h)
        return h

# %%
model = FFNetwork(node_features = lags)
#model = model.to('cuda')

optimizer = torch.optim.Adam(model.parameters(), lr=0.015)
loss_fn = torch.nn.MSELoss()

start_time = time.perf_counter() # Start timer
num_epochs = 400
losses = []
for epoch in range(num_epochs):
    model.train()
    print("  Epoch %d/%d" % (epoch+1,num_epochs))
    X_feature = torch.tensor(X_train, dtype=torch.float32).view(train_size,len(series[0])*lags)
    #snapshot.to('cuda')
    output = model(X_feature)
    y_label = torch.tensor(y_train, dtype=torch.float32)
    loss = loss_fn(output, y_label)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    losses.append(loss.cpu().detach().numpy())
    
    print('Training loss: ', losses[-1])

print(output.shape)
end_time = time.perf_counter() # End timer
print("Elapsed time: ", end_time - start_time) # Calculate elapsed time
output = scaler.inverse_transform(output.cpu().detach().numpy())

plt.plot(losses)
# Out:
#   Epoch 1/400
# Training loss:  1.1316917
#   Epoch 2/400
# Training loss:  0.98297316
#   Epoch 3/400
# Training loss:  0.93070126
#   Epoch 4/400
# Training loss:  0.8696717
#   Epoch 5/400
# Training loss:  0.81932706
#   Epoch 6/400
# Training loss:  0.7834036
#   Epoch 7/400
# Training loss:  0.7587779
#   Epoch 8/400
# Training loss:  0.7417905
#   Epoch 9/400
# Training loss:  0.7272865
#   Epoch 10/400
# Training loss:  0.7158965
#   Epoch 11/400
# Training loss:  0.7072506
#   Epoch 12/400
# Training loss:  0.69961715
#   Epoch 13/400
# Training loss:  0.69290364
#   Epoch 14/400
# Training loss:  0.68684787
#   Epoch 15/400
# Training loss:  0.6818239
#   Epoch 16/400
# Training loss:  0.6772659
#   Epoch 17/400
# Training loss:  0.672534
#   Epoch 18/400
# Training loss:  0.6681803
#   Epoch 19/400
# Training loss:  0.6646247
#   Epoch 20/400
# Training loss:  0.661622
#   Epoch 21/400
# Training loss:  0.65888727
#   Epoch 22/400
# Training loss:  0.65629816
#   Epoch 23/400
# Training loss:  0.6533455
#   Epoch 24/400
# Training loss:  0.64992523
#   Epoch 25/400
# Training loss:  0.64655143
#   Epoch 26/400
# Training loss:  0.643601
#   Epoch 27/400
# Training loss:  0.6409581
#   Epoch 28/400
# Training loss:  0.63879794
#   Epoch 29/400
# Training loss:  0.63712543
#   Epoch 30/400
# Training loss:  0.6354529
#   Epoch 31/400
# Training loss:  0.63339573
#   Epoch 32/400
# Training loss:  0.63116425
#   Epoch 33/400
# Training loss:  0.62907064
#   Epoch 34/400
# Training loss:  0.62718415
#   Epoch 35/400
# Training loss:  0.6255263
#   Epoch 36/400
# Training loss:  0.623988
#   Epoch 37/400
# Training loss:  0.62248003
#   Epoch 38/400
# Training loss:  0.62096846
#   Epoch 39/400
# Training loss:  0.6193998
#   Epoch 40/400
# Training loss:  0.61789626
#   Epoch 41/400
# Training loss:  0.61649644
#   Epoch 42/400
# Training loss:  0.615175
#   Epoch 43/400
# Training loss:  0.61387324
#   Epoch 44/400
# Training loss:  0.61255115
#   Epoch 45/400
# Training loss:  0.6112093
#   Epoch 46/400
# Training loss:  0.60996896
#   Epoch 47/400
# Training loss:  0.6088168
#   Epoch 48/400
# Training loss:  0.6077078
#   Epoch 49/400
# Training loss:  0.60654694
#   Epoch 50/400
# Training loss:  0.6053946
#   Epoch 51/400
# Training loss:  0.60427755
#   Epoch 52/400
# Training loss:  0.60321057
#   Epoch 53/400
# Training loss:  0.60220283
#   Epoch 54/400
# Training loss:  0.60117257
#   Epoch 55/400
# Training loss:  0.6002049
#   Epoch 56/400
# Training loss:  0.59920925
#   Epoch 57/400
# Training loss:  0.59825015
#   Epoch 58/400
# Training loss:  0.59725857
#   Epoch 59/400
# Training loss:  0.5963125
#   Epoch 60/400
# Training loss:  0.59538037
#   Epoch 61/400
# Training loss:  0.5944968
#   Epoch 62/400
# Training loss:  0.59358895
#   Epoch 63/400
# Training loss:  0.59268606
#   Epoch 64/400
# Training loss:  0.59181255
#   Epoch 65/400
# Training loss:  0.59102094
#   Epoch 66/400
# Training loss:  0.59023744
#   Epoch 67/400
# Training loss:  0.58959514
#   Epoch 68/400
# Training loss:  0.5889309
#   Epoch 69/400
# Training loss:  0.5882089
#   Epoch 70/400
# Training loss:  0.5874443
#   Epoch 71/400
# Training loss:  0.58653104
#   Epoch 72/400
# Training loss:  0.5855933
#   Epoch 73/400
# Training loss:  0.5847797
#   Epoch 74/400
# Training loss:  0.58403534
#   Epoch 75/400
# Training loss:  0.58344376
#   Epoch 76/400
# Training loss:  0.5829162
#   Epoch 77/400
# Training loss:  0.5825926
#   Epoch 78/400
# Training loss:  0.582418
#   Epoch 79/400
# Training loss:  0.58215547
#   Epoch 80/400
# Training loss:  0.5811114
#   Epoch 81/400
# Training loss:  0.5796628
#   Epoch 82/400
# Training loss:  0.5784208
#   Epoch 83/400
# Training loss:  0.57795215
#   Epoch 84/400
# Training loss:  0.57791555
#   Epoch 85/400
# Training loss:  0.577804
#   Epoch 86/400
# Training loss:  0.5771472
#   Epoch 87/400
# Training loss:  0.57585776
#   Epoch 88/400
# Training loss:  0.5746548
#   Epoch 89/400
# Training loss:  0.5741208
#   Epoch 90/400
# Training loss:  0.5741237
#   Epoch 91/400
# Training loss:  0.5739794
#   Epoch 92/400
# Training loss:  0.57340926
#   Epoch 93/400
# Training loss:  0.57240045
#   Epoch 94/400
# Training loss:  0.5713899
#   Epoch 95/400
# Training loss:  0.57064325
#   Epoch 96/400
# Training loss:  0.57020676
#   Epoch 97/400
# Training loss:  0.5700343
#   Epoch 98/400
# Training loss:  0.5700735
#   Epoch 99/400
# Training loss:  0.570298
#   Epoch 100/400
# Training loss:  0.5706525
#   Epoch 101/400
# Training loss:  0.5704317
#   Epoch 102/400
# Training loss:  0.5687289
#   Epoch 103/400
# Training loss:  0.5669212
#   Epoch 104/400
# Training loss:  0.5665091
#   Epoch 105/400
# Training loss:  0.5672738
#   Epoch 106/400
# Training loss:  0.5681482
#   Epoch 107/400
# Training loss:  0.56779945
#   Epoch 108/400
# Training loss:  0.5659673
#   Epoch 109/400
# Training loss:  0.56423825
#   Epoch 110/400
# Training loss:  0.56402147
#   Epoch 111/400
# Training loss:  0.56479913
#   Epoch 112/400
# Training loss:  0.564861
#   Epoch 113/400
# Training loss:  0.5637457
#   Epoch 114/400
# Training loss:  0.56222904
#   Epoch 115/400
# Training loss:  0.5619147
#   Epoch 116/400
# Training loss:  0.5624374
#   Epoch 117/400
# Training loss:  0.5626526
#   Epoch 118/400
# Training loss:  0.5618557
#   Epoch 119/400
# Training loss:  0.56058186
#   Epoch 120/400
# Training loss:  0.5599568
#   Epoch 121/400
# Training loss:  0.56009245
#   Epoch 122/400
# Training loss:  0.560343
#   Epoch 123/400
# Training loss:  0.56006354
#   Epoch 124/400
# Training loss:  0.55934227
#   Epoch 125/400
# Training loss:  0.55850744
#   Epoch 126/400
# Training loss:  0.5579102
#   Epoch 127/400
# Training loss:  0.5576464
#   Epoch 128/400
# Training loss:  0.55758524
#   Epoch 129/400
# Training loss:  0.5576028
#   Epoch 130/400
# Training loss:  0.55756104
#   Epoch 131/400
# Training loss:  0.5573601
#   Epoch 132/400
# Training loss:  0.5569668
#   Epoch 133/400
# Training loss:  0.55625427
#   Epoch 134/400
# Training loss:  0.5556277
#   Epoch 135/400
# Training loss:  0.55513716
#   Epoch 136/400
# Training loss:  0.5547694
#   Epoch 137/400
# Training loss:  0.5544606
#   Epoch 138/400
# Training loss:  0.55418205
#   Epoch 139/400
# Training loss:  0.55391276
#   Epoch 140/400
# Training loss:  0.553613
#   Epoch 141/400
# Training loss:  0.55335337
#   Epoch 142/400
# Training loss:  0.55310625
#   Epoch 143/400
# Training loss:  0.55283314
#   Epoch 144/400
# Training loss:  0.55288476
#   Epoch 145/400
# Training loss:  0.55352473
#   Epoch 146/400
# Training loss:  0.5557841
#   Epoch 147/400
# Training loss:  0.55989397
#   Epoch 148/400
# Training loss:  0.56273997
#   Epoch 149/400
# Training loss:  0.5592741
#   Epoch 150/400
# Training loss:  0.5519005
#   Epoch 151/400
# Training loss:  0.55331403
#   Epoch 152/400
# Training loss:  0.5575619
#   Epoch 153/400
# Training loss:  0.5532875
#   Epoch 154/400
# Training loss:  0.5504413
#   Epoch 155/400
# Training loss:  0.5536048
#   Epoch 156/400
# Training loss:  0.55261666
#   Epoch 157/400
# Training loss:  0.5496864
#   Epoch 158/400
# Training loss:  0.5510079
#   Epoch 159/400
# Training loss:  0.5513347
#   Epoch 160/400
# Training loss:  0.5490986
#   Epoch 161/400
# Training loss:  0.54949886
#   Epoch 162/400
# Training loss:  0.55025136
#   Epoch 163/400
# Training loss:  0.54857755
#   Epoch 164/400
# Training loss:  0.5483199
#   Epoch 165/400
# Training loss:  0.5490928
#   Epoch 166/400
# Training loss:  0.54821306
#   Epoch 167/400
# Training loss:  0.54731506
#   Epoch 168/400
# Training loss:  0.5477913
#   Epoch 169/400
# Training loss:  0.5475957
#   Epoch 170/400
# Training loss:  0.5466869
#   Epoch 171/400
# Training loss:  0.5464999
#   Epoch 172/400
# Training loss:  0.5466527
#   Epoch 173/400
# Training loss:  0.546362
#   Epoch 174/400
# Training loss:  0.545776
#   Epoch 175/400
# Training loss:  0.54553455
#   Epoch 176/400
# Training loss:  0.545607
#   Epoch 177/400
# Training loss:  0.54545224
#   Epoch 178/400
# Training loss:  0.54506564
#   Epoch 179/400
# Training loss:  0.54460824
#   Epoch 180/400
# Training loss:  0.54443634
#   Epoch 181/400
# Training loss:  0.544346
#   Epoch 182/400
# Training loss:  0.5442065
#   Epoch 183/400
# Training loss:  0.54386926
#   Epoch 184/400
# Training loss:  0.54359025
#   Epoch 185/400
# Training loss:  0.5433243
#   Epoch 186/400
# Training loss:  0.54310095
#   Epoch 187/400
# Training loss:  0.5429092
#   Epoch 188/400
# Training loss:  0.54272777
#   Epoch 189/400
# Training loss:  0.54265225
#   Epoch 190/400
# Training loss:  0.54253703
#   Epoch 191/400
# Training loss:  0.542509
#   Epoch 192/400
# Training loss:  0.54251814
#   Epoch 193/400
# Training loss:  0.5425165
#   Epoch 194/400
# Training loss:  0.5422632
#   Epoch 195/400
# Training loss:  0.5418309
#   Epoch 196/400
# Training loss:  0.54148394
#   Epoch 197/400
# Training loss:  0.541099
#   Epoch 198/400
# Training loss:  0.54091233
#   Epoch 199/400
# Training loss:  0.54072523
#   Epoch 200/400
# Training loss:  0.54057115
#   Epoch 201/400
# Training loss:  0.5404924
#   Epoch 202/400
# Training loss:  0.54052746
#   Epoch 203/400
# Training loss:  0.54080653
#   Epoch 204/400
# Training loss:  0.54156804
#   Epoch 205/400
# Training loss:  0.5429493
#   Epoch 206/400
# Training loss:  0.54454356
#   Epoch 207/400
# Training loss:  0.5452206
#   Epoch 208/400
# Training loss:  0.54330045
#   Epoch 209/400
# Training loss:  0.54018295
#   Epoch 210/400
# Training loss:  0.53841543
#   Epoch 211/400
# Training loss:  0.53927195
#   Epoch 212/400
# Training loss:  0.5409734
#   Epoch 213/400
# Training loss:  0.5417612
#   Epoch 214/400
# Training loss:  0.5402736
#   Epoch 215/400
# Training loss:  0.5381201
#   Epoch 216/400
# Training loss:  0.53739786
#   Epoch 217/400
# Training loss:  0.5382735
#   Epoch 218/400
# Training loss:  0.53910065
#   Epoch 219/400
# Training loss:  0.5388052
#   Epoch 220/400
# Training loss:  0.53752804
#   Epoch 221/400
# Training loss:  0.53657544
#   Epoch 222/400
# Training loss:  0.5363403
#   Epoch 223/400
# Training loss:  0.53672737
#   Epoch 224/400
# Training loss:  0.5371143
#   Epoch 225/400
# Training loss:  0.53695184
#   Epoch 226/400
# Training loss:  0.53641456
#   Epoch 227/400
# Training loss:  0.5357391
#   Epoch 228/400
# Training loss:  0.535229
#   Epoch 229/400
# Training loss:  0.5349878
#   Epoch 230/400
# Training loss:  0.53508425
#   Epoch 231/400
# Training loss:  0.53516954
#   Epoch 232/400
# Training loss:  0.5354661
#   Epoch 233/400
# Training loss:  0.53572226
#   Epoch 234/400
# Training loss:  0.53602463
#   Epoch 235/400
# Training loss:  0.5361198
#   Epoch 236/400
# Training loss:  0.53548956
#   Epoch 237/400
# Training loss:  0.5345205
#   Epoch 238/400
# Training loss:  0.53392863
#   Epoch 239/400
# Training loss:  0.5333412
#   Epoch 240/400
# Training loss:  0.5330279
#   Epoch 241/400
# Training loss:  0.5331044
#   Epoch 242/400
# Training loss:  0.5331729
#   Epoch 243/400
# Training loss:  0.53382033
#   Epoch 244/400
# Training loss:  0.5347712
#   Epoch 245/400
# Training loss:  0.53615594
#   Epoch 246/400
# Training loss:  0.5372424
#   Epoch 247/400
# Training loss:  0.53749007
#   Epoch 248/400
# Training loss:  0.535726
#   Epoch 249/400
# Training loss:  0.5329846
#   Epoch 250/400
# Training loss:  0.53158075
#   Epoch 251/400
# Training loss:  0.53245807
#   Epoch 252/400
# Training loss:  0.53435266
#   Epoch 253/400
# Training loss:  0.53533185
#   Epoch 254/400
# Training loss:  0.5344789
#   Epoch 255/400
# Training loss:  0.53228444
#   Epoch 256/400
# Training loss:  0.53070843
#   Epoch 257/400
# Training loss:  0.5309253
#   Epoch 258/400
# Training loss:  0.53213304
#   Epoch 259/400
# Training loss:  0.533125
#   Epoch 260/400
# Training loss:  0.5328256
#   Epoch 261/400
# Training loss:  0.53144306
#   Epoch 262/400
# Training loss:  0.5300838
#   Epoch 263/400
# Training loss:  0.529686
#   Epoch 264/400
# Training loss:  0.53027123
#   Epoch 265/400
# Training loss:  0.53113663
#   Epoch 266/400
# Training loss:  0.53178316
#   Epoch 267/400
# Training loss:  0.5316055
#   Epoch 268/400
# Training loss:  0.5307661
#   Epoch 269/400
# Training loss:  0.52956855
#   Epoch 270/400
# Training loss:  0.52880144
#   Epoch 271/400
# Training loss:  0.52873355
#   Epoch 272/400
# Training loss:  0.52905315
#   Epoch 273/400
# Training loss:  0.5295864
#   Epoch 274/400
# Training loss:  0.53008014
#   Epoch 275/400
# Training loss:  0.5302329
#   Epoch 276/400
# Training loss:  0.5300003
#   Epoch 277/400
# Training loss:  0.5294139
#   Epoch 278/400
# Training loss:  0.5287324
#   Epoch 279/400
# Training loss:  0.5282092
#   Epoch 280/400
# Training loss:  0.5277339
#   Epoch 281/400
# Training loss:  0.5274312
#   Epoch 282/400
# Training loss:  0.5273208
#   Epoch 283/400
# Training loss:  0.5273171
#   Epoch 284/400
# Training loss:  0.5273962
#   Epoch 285/400
# Training loss:  0.52764773
#   Epoch 286/400
# Training loss:  0.52831703
#   Epoch 287/400
# Training loss:  0.52959603
#   Epoch 288/400
# Training loss:  0.5315556
#   Epoch 289/400
# Training loss:  0.5334593
#   Epoch 290/400
# Training loss:  0.5347619
#   Epoch 291/400
# Training loss:  0.5327355
#   Epoch 292/400
# Training loss:  0.5289835
#   Epoch 293/400
# Training loss:  0.5264278
#   Epoch 294/400
# Training loss:  0.527114
#   Epoch 295/400
# Training loss:  0.5295773
#   Epoch 296/400
# Training loss:  0.5312832
#   Epoch 297/400
# Training loss:  0.5302487
#   Epoch 298/400
# Training loss:  0.5275461
#   Epoch 299/400
# Training loss:  0.5257926
#   Epoch 300/400
# Training loss:  0.5264489
#   Epoch 301/400
# Training loss:  0.5282647
#   Epoch 302/400
# Training loss:  0.5286494
#   Epoch 303/400
# Training loss:  0.52743185
#   Epoch 304/400
# Training loss:  0.525776
#   Epoch 305/400
# Training loss:  0.5251051
#   Epoch 306/400
# Training loss:  0.52578664
#   Epoch 307/400
# Training loss:  0.52673787
#   Epoch 308/400
# Training loss:  0.52666813
#   Epoch 309/400
# Training loss:  0.525978
#   Epoch 310/400
# Training loss:  0.5251401
#   Epoch 311/400
# Training loss:  0.52445793
#   Epoch 312/400
# Training loss:  0.5245252
#   Epoch 313/400
# Training loss:  0.5248769
#   Epoch 314/400
# Training loss:  0.5252354
#   Epoch 315/400
# Training loss:  0.52566177
#   Epoch 316/400
# Training loss:  0.5257952
#   Epoch 317/400
# Training loss:  0.5255168
#   Epoch 318/400
# Training loss:  0.52501184
#   Epoch 319/400
# Training loss:  0.524354
#   Epoch 320/400
# Training loss:  0.5237609
#   Epoch 321/400
# Training loss:  0.52354723
#   Epoch 322/400
# Training loss:  0.52356106
#   Epoch 323/400
# Training loss:  0.523636
#   Epoch 324/400
# Training loss:  0.5239956
#   Epoch 325/400
# Training loss:  0.5246515
#   Epoch 326/400
# Training loss:  0.5255918
#   Epoch 327/400
# Training loss:  0.5266954
#   Epoch 328/400
# Training loss:  0.5278831
#   Epoch 329/400
# Training loss:  0.52872247
#   Epoch 330/400
# Training loss:  0.5280812
#   Epoch 331/400
# Training loss:  0.52615345
#   Epoch 332/400
# Training loss:  0.5237216
#   Epoch 333/400
# Training loss:  0.5227088
#   Epoch 334/400
# Training loss:  0.52353257
#   Epoch 335/400
# Training loss:  0.5252555
#   Epoch 336/400
# Training loss:  0.5265959
#   Epoch 337/400
# Training loss:  0.52668786
#   Epoch 338/400
# Training loss:  0.52549803
#   Epoch 339/400
# Training loss:  0.52371556
#   Epoch 340/400
# Training loss:  0.5222803
#   Epoch 341/400
# Training loss:  0.52244025
#   Epoch 342/400
# Training loss:  0.523723
#   Epoch 343/400
# Training loss:  0.5246533
#   Epoch 344/400
# Training loss:  0.52475
#   Epoch 345/400
# Training loss:  0.52374077
#   Epoch 346/400
# Training loss:  0.52239966
#   Epoch 347/400
# Training loss:  0.5216729
#   Epoch 348/400
# Training loss:  0.5217575
#   Epoch 349/400
# Training loss:  0.5224534
#   Epoch 350/400
# Training loss:  0.52333343
#   Epoch 351/400
# Training loss:  0.52388585
#   Epoch 352/400
# Training loss:  0.52382755
#   Epoch 353/400
# Training loss:  0.52317584
#   Epoch 354/400
# Training loss:  0.5222515
#   Epoch 355/400
# Training loss:  0.52139163
#   Epoch 356/400
# Training loss:  0.520939
#   Epoch 357/400
# Training loss:  0.5209328
#   Epoch 358/400
# Training loss:  0.5212406
#   Epoch 359/400
# Training loss:  0.52190554
#   Epoch 360/400
# Training loss:  0.52283996
#   Epoch 361/400
# Training loss:  0.52368647
#   Epoch 362/400
# Training loss:  0.5242567
#   Epoch 363/400
# Training loss:  0.52427185
#   Epoch 364/400
# Training loss:  0.5234355
#   Epoch 365/400
# Training loss:  0.52209413
#   Epoch 366/400
# Training loss:  0.5208086
#   Epoch 367/400
# Training loss:  0.5201504
#   Epoch 368/400
# Training loss:  0.520149
#   Epoch 369/400
# Training loss:  0.520665
#   Epoch 370/400
# Training loss:  0.5215081
#   Epoch 371/400
# Training loss:  0.522615
#   Epoch 372/400
# Training loss:  0.5238271
#   Epoch 373/400
# Training loss:  0.5244976
#   Epoch 374/400
# Training loss:  0.5239971
#   Epoch 375/400
# Training loss:  0.5223785
#   Epoch 376/400
# Training loss:  0.5205394
#   Epoch 377/400
# Training loss:  0.51950693
#   Epoch 378/400
# Training loss:  0.519633
#   Epoch 379/400
# Training loss:  0.5206055
#   Epoch 380/400
# Training loss:  0.5220271
#   Epoch 381/400
# Training loss:  0.5233129
#   Epoch 382/400
# Training loss:  0.5238981
#   Epoch 383/400
# Training loss:  0.52308774
#   Epoch 384/400
# Training loss:  0.5211173
#   Epoch 385/400
# Training loss:  0.5194786
#   Epoch 386/400
# Training loss:  0.5190225
#   Epoch 387/400
# Training loss:  0.5197362
#   Epoch 388/400
# Training loss:  0.521008
#   Epoch 389/400
# Training loss:  0.5224836
#   Epoch 390/400
# Training loss:  0.52307355
#   Epoch 391/400
# Training loss:  0.52232987
#   Epoch 392/400
# Training loss:  0.5206871
#   Epoch 393/400
# Training loss:  0.5190766
#   Epoch 394/400
# Training loss:  0.5186036
#   Epoch 395/400
# Training loss:  0.51909554
#   Epoch 396/400
# Training loss:  0.52011985
#   Epoch 397/400
# Training loss:  0.5213816
#   Epoch 398/400
# Training loss:  0.522394
#   Epoch 399/400
# Training loss:  0.522073
#   Epoch 400/400
# Training loss:  0.5207417
# torch.Size([6350, 24])
# Elapsed time:  0.7053531399978965

# %%
model.eval()

X_feature = torch.tensor(X_test, dtype=torch.float32).view(test_size, len(series[0])*lags)
output_test = model(X_feature)
y_label = torch.tensor(y_test, dtype=torch.float32)
loss = loss_fn(output_test, y_label)
outputs_test = scaler.inverse_transform(output_test.cpu().detach().numpy())
loss.item()
# Out:
# 0.8456549644470215

# %%
y_train = scaler.inverse_transform(y_train)
y_test = scaler.inverse_transform(y_test)
y_train
# Out:
# array([[24.  , 24.  , 24.01, ..., 44.4 , 44.12, 39.42],
#        [24.  , 24.  , 24.  , ..., 48.07, 42.76, 30.09],
#        [23.99, 24.  ,  6.44, ..., 44.63, 41.23, 35.7 ],
#        ...,
#        [18.4 , 18.39, 18.35, ..., 18.45, 17.42, 15.37],
#        [14.05, 14.18, 14.89, ..., 17.37, 15.39, 15.31],
#        [15.38, 15.4 , 16.14, ..., 22.98, 20.91, 18.87]])

# %%
outputs_hourly = []
y_label_hourly = []
outputs_test_hourly = []
y_label_test_hourly = []
for j in range(24):
    outputs_h = [output[i][j] for i in range(len(output))]
    outputs_hourly.append(outputs_h)
    y_label_h = [y_train[i][j] for i in range(len(output))]
    y_label_hourly.append(y_label_h)
    outputs_test_h = [outputs_test[i][j] for i in range(len(outputs_test))]
    outputs_test_hourly.append(outputs_test_h)
    y_label_test_h = [y_test[i][j] for i in range(len(outputs_test))]
    y_label_test_hourly.append(y_label_test_h)

# %%
# for day in y_train:
#     day*max_hourly

# for day in y_test:
#     day*max_hourly

# %%
mse_train = []
residuals_train = []
mse_test = []
mae_test = []
residuals_test = []
for j in range(24):
    diff = [a - b for a,b in zip(y_label_hourly[j],outputs_hourly[j])]
    squared_diff = [(a - b)**2 for a,b in zip(y_label_hourly[j],outputs_hourly[j])]
    mse_train.append(np.mean(squared_diff))
    residuals_train.append(diff)
    diffabs = [abs(a - b) for a,b in zip(y_label_test_hourly[j],outputs_test_hourly[j])]
    diff = [a - b for a,b in zip(y_label_test_hourly[j],outputs_test_hourly[j])]
    squared_diff = [(a - b)**2 for a,b in zip(y_label_test_hourly[j],outputs_test_hourly[j])]
    mae_test.append(np.mean(diffabs))
    mse_test.append(np.mean(squared_diff))
    residuals_test.append(diff)

mse_train
# Out:
# [527.6819657028203,
#  453.85923082281425,
#  242.43769514553492,
#  196.344034149394,
#  238.13856133532477,
#  358.39244109774404,
#  2504.276184250667,
#  2621.0383626143052,
#  3732.3162929881987,
#  5172.073695826548,
#  7363.669046446437,
#  9185.109318304667,
#  9286.677774496127,
#  10593.180901066886,
#  10965.679976066704,
#  11032.773138100361,
#  13473.302721850632,
#  17720.068703673576,
#  11246.724896236621,
#  8585.361959985561,
#  6398.71136319088,
#  5747.779339317042,
#  1510.9078965562326,
#  1644.179074050522]

# %%
np.mean(mae_test)
# Out:
# 38.46607685347947

# %%
mse_test
# Out:
# array([  625.21726826,   322.75530029,   215.38946414,   369.58610469,
#          496.47019385,  1147.58898599,  3492.37738774,  5278.22591362,
#         7053.20166361, 10676.84613929, 15422.25870734, 18312.35571131,
#        15370.02720394, 18282.17691291, 19031.77827013, 20225.84587849,
#        25729.16482528, 28537.8726583 , 18254.44409034, 13268.71714323,
#         9477.56745151,  5637.90335935,  2486.37741543,  1775.66372242])

# %%
np.mean(mse_test)
# Out:
# 10062.07549047777

# %%
np.array(mse_train).shape
# Out:
# (24,)

# %%
mse_train = np.array(mse_train)
mse_test = np.array(mse_test)
mse_train
#np.mean(mse_train)
# Out:
# array([  527.6819657 ,   453.85923082,   242.43769515,   196.34403415,
#          238.13856134,   358.3924411 ,  2504.27618425,  2621.03836261,
#         3732.31629299,  5172.07369583,  7363.66904645,  9185.1093183 ,
#         9286.6777745 , 10593.18090107, 10965.67997607, 11032.7731381 ,
#        13473.30272185, 17720.06870367, 11246.72489624,  8585.36195999,
#         6398.71136319,  5747.77933932,  1510.90789656,  1644.17907405])

# %%
np.mean(mse_test/(sigma**2))
# Out:
# 0.7885433014950984

# %%
np.mean(mse_train/(sigma**2))
# Out:
# 0.6843557884470091

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(y_label_hourly[0][:200],label='Ground Truth')
plt.plot(outputs_hourly[0][:200],label='FFN')
#plt.plot(outputs_test)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(y_label_test_hourly[0][:200],label='Ground Truth')
plt.plot(outputs_test_hourly[0][:200],label='FFN')
#plt.plot(outputs_test)
plt.legend()
plt.show()

# %%
#NAIVE(non rirunnare)
series = scaler.inverse_transform(series)

# %%
y_train_naive = series[1:train_size+1]
y_test_naive = series[train_size+1:]
len(y_train_naive)
# Out:
# 6421

# %%
len(y_test_naive)
y_train_naive[0]
# Out:
# array([ 11.67,   5.9 ,   5.9 ,   5.85,   5.85,   5.85,   5.9 ,  17.03,
#         20.46,  21.04,  22.11,  30.41,  30.41,  30.44,  32.19,  31.09,
#         40.19, 388.07,  65.12,  58.1 ,  51.14,  51.13,  35.09,  30.51])

# %%
#check
np.max(y_test_naive, axis=0)
# Out:
# array([999.99, 742.59, 442.57, 664.92, 656.35, 824.01, 926.64, 998.75,
#        999.65, 999.99, 999.99, 997.02, 976.  , 965.32, 999.54, 999.99,
#        999.99, 999.99, 999.99, 999.99, 999.99, 999.99, 999.99, 999.99])

# %%
naive_series = series[:-1,:]
len(naive_series)
#len(series)
naive_series#[:,0]
# Out:
# array([[ 21.65,  21.  ,   5.9 , ...,  27.31,  21.5 ,  15.13],
#        [ 11.67,   5.9 ,   5.9 , ...,  51.13,  35.09,  30.51],
#        [ 25.54,  21.  ,  21.  , ...,  33.18,  30.87,  21.63],
#        ...,
#        [999.99, 742.59, 228.81, ...,  45.69,  38.09,  41.92],
#        [ 44.46,  60.62,  63.58, ...,  45.07,  42.02,  46.06],
#        [ 42.16,  37.5 ,  35.1 , ...,  84.94,  74.68,  74.62]])

# %%
naive_train = naive_series[:train_size]
naive_test = naive_series[train_size:]
len(naive_test)
naive_train[0]
# Out:
# array([21.65, 21.  ,  5.9 ,  5.85,  5.84,  5.9 ,  5.9 ,  6.52, 20.99,
#        20.99, 21.6 , 21.5 , 21.51, 21.59, 21.5 , 21.75, 27.02, 28.57,
#        27.48, 27.48, 24.23, 27.31, 21.5 , 15.13])

# %%
outputs_hourly = []
y_label_hourly = []
outputs_test_hourly = []
y_label_test_hourly = []
for j in range(24):
    outputs_hourly.append(list(naive_train[:,j]))
    y_label_h = [y_train_naive[i][j] for i in range(len(naive_train))]
    y_label_hourly.append(y_label_h)
    outputs_test_hourly.append(list(naive_test[:,j]))
    y_label_test_h = [y_test_naive[i][j] for i in range(len(naive_test)-2)]
    y_label_test_hourly.append(y_label_test_h)

# %%
#y_label_hourly[0]

# %%
mse_train_naive = []
residuals_train = []
mse_test_naive = []
residuals_test = []
for j in range(24):
    diff = [a - b for a,b in zip(y_label_hourly[j],outputs_hourly[j])]
    squared_diff = [(a - b)**2 for a,b in zip(y_label_hourly[j],outputs_hourly[j])]
    mse_train_naive.append(np.mean(squared_diff))
    residuals_train.append(diff)
    diff = [a - b for a,b in zip(y_label_test_hourly[j],outputs_test_hourly[j])]
    squared_diff = [(a - b)**2 for a,b in zip(y_label_test_hourly[j],outputs_test_hourly[j])]
    mse_test_naive.append(np.mean(squared_diff))
    residuals_test.append(diff)

mse_train_naive
# Out:
# [1361.741675408815,
#  1062.311342763121,
#  568.2495389658931,
#  391.97803778227694,
#  502.9293275969475,
#  785.834531365831,
#  5502.635014530447,
#  5865.345977558014,
#  8694.09224183149,
#  12799.08633767326,
#  17277.49114142657,
#  20582.97998674661,
#  19938.211523859212,
#  21677.77715872917,
#  22067.998098364744,
#  21430.382158511136,
#  25582.877138545395,
#  31501.311480330165,
#  20373.257729792866,
#  16238.606036769972,
#  11868.747937377355,
#  10244.645359040647,
#  2606.553845693817,
#  2762.570913658308]

# %% [markdown]
# mse dai benchmark

# %%
mse_var = pd.read_csv('data/mse_var.csv')
mse_var['mse_train_ffn'] = mse_train
mse_var['mse_test_ffn'] = mse_test
#mse_var['mse_train_naive'] = mse_train_naive
#mse_var['mse_test_test_naive'] = mse_test_naive 
mse_var = mse_var.round(1).applymap(lambda x: f'{x:.1f}'.rstrip('0').rstrip('.'))
mse_var
# Out:
#    mse_train mse_test mae_test mse_train_ffn mse_test_ffn
# 0      576.3    549.4      7.6         527.7        625.2
# 1      492.9    283.1      6.8         453.9        322.8
# 2        279    197.6      6.6         242.4        215.4
# 3      218.5    307.2      6.8         196.3        369.6
# 4      279.5    440.6      7.4         238.1        496.5
# 5      407.1   1101.5        9         358.4       1147.6
# 6     2688.1   3439.4     19.4        2504.3       3492.4
# 7     3051.5   4960.1     25.4          2621       5278.2
# 8     4289.9   5835.6     28.7        3732.3       7053.2
# 9     5862.8   8075.2     34.1        5172.1      10676.8
# 10    8748.8  10869.1     44.3        7363.7      15422.3
# 11   11657.6  12106.1     48.4        9185.1      18312.4
# 12   11839.1  10661.6     47.1        9286.7        15370
# 13   13136.3  14019.4     52.7       10593.2      18282.2
# 14   13754.6  14148.4     52.1       10965.7      19031.8
# 15   13867.2  15215.4     55.6       11032.8      20225.8
# 16   17884.1  21078.3     64.5       13473.3      25729.2
# 17   20826.7    23068       82       17720.1      28537.9
# 18   13218.1  15757.2     59.1       11246.7      18254.4
# 19   10000.2  11962.9     49.4        8585.4      13268.7
# 20    7510.8   8373.3     40.1        6398.7       9477.6
# 21      6418   4365.6     30.8        5747.8       5637.9
# 22    1671.5   2192.9       17        1510.9       2486.4
# 23    1645.1     1679     15.5        1644.2       1775.7

# %%
print(mse_var.to_latex(index=False))
# Out:
# \begin{tabular}{llllll}
# \toprule
# mse_train & mse_test & mse_train_ffn & mse_test_ffn & mse_train_naive & mse_test_ffn_naive \\
# \midrule
# 575.7 & 549.4 & 530.1 & 825.4 & 1361.7 & 1509.6 \\
# 621.7 & 600 & 454.8 & 449.9 & 1062.3 & 590.8 \\
# 672.7 & 732.6 & 252.9 & 225.1 & 568.2 & 299.6 \\
# 719.5 & 772 & 199.3 & 410.3 & 392 & 668.9 \\
# 706.2 & 774.1 & 245.9 & 538.9 & 502.9 & 845 \\
# 668.7 & 717.3 & 367.8 & 1134 & 785.8 & 2005.6 \\
# 1264.4 & 1020.2 & 2516.3 & 3578 & 5502.6 & 5958.2 \\
# 2129.2 & 1515.8 & 2660.6 & 5707.8 & 5865.3 & 7907.1 \\
# 3034.3 & 1988 & 3675.4 & 6951.5 & 8694.1 & 9477.4 \\
# 4122.8 & 2359.4 & 5280.8 & 9505.7 & 12799.1 & 12482.7 \\
# 6638.1 & 3784.8 & 7247.3 & 12939.8 & 17277.5 & 17692.9 \\
# 9387.4 & 4897 & 8832.3 & 15554.2 & 20583 & 19389.5 \\
# 9165.5 & 4765.5 & 8899.7 & 13639.1 & 19938.2 & 16808.4 \\
# 10029.6 & 5166.5 & 10038.3 & 17224.2 & 21677.8 & 22884.7 \\
# 10404.9 & 5536.1 & 10405.3 & 16996 & 22068 & 19333.9 \\
# 10793 & 5821.5 & 10309.2 & 18460.9 & 21430.4 & 20696.7 \\
# 13224.3 & 8451.9 & 13023.3 & 23232.9 & 25582.9 & 27871.9 \\
# 17711.5 & 12727.7 & 17963.7 & 26304.2 & 31501.3 & 30934.3 \\
# 8491.1 & 7184.2 & 11032.6 & 17706 & 20373.3 & 20566.6 \\
# 5900.4 & 4571.3 & 8386 & 12942.9 & 16238.6 & 16825.9 \\
# 4752.8 & 2743.4 & 6445 & 8792.4 & 11868.7 & 12433 \\
# 4057.6 & 1803.7 & 5596.3 & 4970.5 & 10244.6 & 6767.3 \\
# 1208.2 & 801.3 & 1558.4 & 2112.2 & 2606.6 & 3465.8 \\
# 864.6 & 674.1 & 1627.8 & 1627.2 & 2762.6 & 2354.1 \\
# \bottomrule
# \end{tabular}
