# %%
import json
import numpy as np
import torch
from torch_geometric_temporal.signal import StaticGraphTemporalSignal
import time

#torch.set_default_device('cuda:0')
#torch.cuda.is_available()

# %%
class MyStaticDatasetLoader(object):
    def __init__(self):
        self._read_web_data()

    def _read_web_data(self):
        with open('data/graphs/grafo_correlazione.json') as f:
            self._dataset = json.load(f)

    def _get_edges(self):
        self._edges = np.array(self._dataset["edges"]).T

    def _get_edge_weights(self):
        self._edge_weights = np.array(self._dataset["edge_weights"])

    def _get_node_ids(self):
        self._node_ids = np.array(self._dataset["node_ids"])
    
    def _get_targets_and_features(self):
        stacked_target = np.array(self._dataset["series"])
        self.scale = []
        for i in range(24):
            self.scale.append(max(stacked_target[:,i]))
        self.scale = np.array(self.scale)
        self.mu = np.mean(stacked_target, axis=0)
        self.sigma = np.std(stacked_target, axis=0)
        standardized_target = (stacked_target - self.mu) / (self.sigma + 10 ** -10)
        #standardized_target = stacked_target/self.scale
        self.features = [
            standardized_target[i : i + self.lags, :].T
            for i in range(standardized_target.shape[0] - self.lags)
        ]
        self.targets = [
            standardized_target[i + self.lags, :].T
            for i in range(standardized_target.shape[0] - self.lags)
        ]

    def get_dataset(self, lags: int = 4) -> StaticGraphTemporalSignal:
        self.lags = lags
        self._get_edges()
        self._get_edge_weights()
        self._get_node_ids()
        self._get_targets_and_features()
        dataset = StaticGraphTemporalSignal(
            self._edges, self._edge_weights, self.features, self.targets
        )
        return dataset

lags = 3
out_channels = 30
loader = MyStaticDatasetLoader()
dataset = loader.get_dataset(lags=lags)
dataset[1]
# Out:
# Data(x=[24, 3], edge_index=[2, 282], edge_attr=[282], y=[24])

# %%
import torch.nn.functional as F
from matplotlib import pyplot as plt
from torch_geometric_temporal.nn.recurrent import GConvGRU, DCRNN, TGCN
from torch_geometric_temporal.signal import temporal_signal_split

train_dataset, test_dataset = temporal_signal_split(dataset, train_ratio=0.8)
#train_dataset[6420]

# %%
class RecurrentGCN(torch.nn.Module):
    def __init__(self, node_features):
        super(RecurrentGCN, self).__init__()
        self.recurrent = TGCN(in_channels=node_features, out_channels=out_channels, add_self_loops=False)
        self.linear = torch.nn.Linear(out_channels, 1)

    def forward(self, x, edge_index, edge_weight, H):
        H = self.recurrent(x, edge_index, edge_weight, H)
        h = H
        h = F.relu(h)
        h = self.linear(h)
        return h,H

# %%
model = RecurrentGCN(node_features = lags)
name_model = model.recurrent.__class__.__name__
name_model
# Out:
# 'TGCN'

# %%
'''
model = RecurrentGCN(node_features = lags)
#model = model.to('cuda')
model.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.2)
loss_fn = F.mse_loss

start_time = time.perf_counter() # Start timer
num_epochs = 50
losses = []

for epoch in range(num_epochs):
    loss = 0
    print("  Epoch %d/%d" % (epoch+1,num_epochs))
    for time_step, snapshot in enumerate(train_dataset):
        #snapshot.to('cuda')
        output = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr)
        loss = loss + loss_fn(output.T[0], snapshot.y)

    print(output[:,0])
    loss = loss/(time_step+1)
    
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    losses.append(loss.cpu().detach().numpy())
    
    print('Training loss: ', losses[-1])

end_time = time.perf_counter() # End timer
print("Elapsed time: ", end_time - start_time) # Calculate elapsed time

plt.plot(losses)

'''
# Out:
# '\nmodel = RecurrentGCN(node_features = lags)\n#model = model.to(\'cuda\')\nmodel.train()\n\noptimizer = torch.optim.Adam(model.parameters(), lr=0.2)\nloss_fn = F.mse_loss\n\nstart_time = time.perf_counter() # Start timer\nnum_epochs = 50\nlosses = []\n\nfor epoch in range(num_epochs):\n    loss = 0\n    print("  Epoch %d/%d" % (epoch+1,num_epochs))\n    for time_step, snapshot in enumerate(train_dataset):\n        #snapshot.to(\'cuda\')\n        output = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr)\n        loss = loss + loss_fn(output.T[0], snapshot.y)\n\n    print(output[:,0])\n    loss = loss/(time_step+1)\n    \n    loss.backward()\n    optimizer.step()\n    optimizer.zero_grad()\n    \n    losses.append(loss.cpu().detach().numpy())\n    \n    print(\'Training loss: \', losses[-1])\n\nend_time = time.perf_counter() # End timer\nprint("Elapsed time: ", end_time - start_time) # Calculate elapsed time\n\nplt.plot(losses)\n\n'

# %%
sigma = loader.sigma
mu = loader.mu
scale = loader.scale
def descale(output, sigma, mu, scale):
    return output*sigma + mu#scale

# %%
#model = model.to('cuda')
model.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.092) #, weight_decay=0.01
loss_fn = F.mse_loss

start_time = time.perf_counter() # Start timer
num_epochs = 100
losses = []
outputs = []  #
targets = []  #
for epoch in range(num_epochs):
    loss = 0
    epoch_outputs = []  #
    epoch_targets = []  #
    H = torch.zeros(24,out_channels)
    print("  Epoch %d/%d" % (epoch+1,num_epochs))
    for time_step, snapshot in enumerate(train_dataset):
        #snapshot.to('cuda')
        output, H = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr, H=H)
        descaled_output = descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale)
        descaled_snapshot = descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale)
        loss = loss + loss_fn(output.T[0], snapshot.y)
        epoch_outputs.append(descaled_output)  #
        epoch_targets.append(descaled_snapshot)   #

    loss = loss/(time_step+1)
    
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    losses.append(loss.cpu().detach().numpy())
    outputs.append(epoch_outputs)  #
    targets.append(epoch_targets)  #
    print('Training loss: ', losses[-1])

end_time = time.perf_counter() # End timer
print("Elapsed time: ", end_time - start_time) # Calculate elapsed time
 
plt.plot(losses)
plt.xlabel("epoch")
# Out:
#   Epoch 1/100
# /opt/tljh/user/envs/py312_geomtemp_090624/lib/python3.12/site-packages/torch/autograd/__init__.py:266: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /opt/conda/conda-bld/pytorch_1704987289929/work/c10/cuda/CUDAFunctions.cpp:108.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Training loss:  1.0627842
#   Epoch 2/100
# Training loss:  0.82615864
#   Epoch 3/100
# Training loss:  0.90111583
#   Epoch 4/100
# Training loss:  0.82018393
#   Epoch 5/100
# Training loss:  0.82047534
#   Epoch 6/100
# Training loss:  0.7661672
#   Epoch 7/100
# Training loss:  0.7451467
#   Epoch 8/100
# Training loss:  0.73941004
#   Epoch 9/100
# Training loss:  0.7427733
#   Epoch 10/100
# Training loss:  0.7377299
#   Epoch 11/100
# Training loss:  0.734592
#   Epoch 12/100
# Training loss:  0.73168874
#   Epoch 13/100
# Training loss:  0.7268285
#   Epoch 14/100
# Training loss:  0.7220072
#   Epoch 15/100
# Training loss:  0.7199584
#   Epoch 16/100
# Training loss:  0.71679044
#   Epoch 17/100
# Training loss:  0.71521866
#   Epoch 18/100
# Training loss:  0.71298635
#   Epoch 19/100
# Training loss:  0.7120362
#   Epoch 20/100
# Training loss:  0.71128875
#   Epoch 21/100
# Training loss:  0.70992184
#   Epoch 22/100
# Training loss:  0.70994854
#   Epoch 23/100
# Training loss:  0.7080572
#   Epoch 24/100
# Training loss:  0.704983
#   Epoch 25/100
# Training loss:  0.7040344
#   Epoch 26/100
# Training loss:  0.7032385
#   Epoch 27/100
# Training loss:  0.70208526
#   Epoch 28/100
# Training loss:  0.70140874
#   Epoch 29/100
# Training loss:  0.7000571
#   Epoch 30/100
# Training loss:  0.6994224
#   Epoch 31/100
# Training loss:  0.6984613
#   Epoch 32/100
# Training loss:  0.69769055
#   Epoch 33/100
# Training loss:  0.69654006
#   Epoch 34/100
# Training loss:  0.69542664
#   Epoch 35/100
# Training loss:  0.6945006
#   Epoch 36/100
# Training loss:  0.6939136
#   Epoch 37/100
# Training loss:  0.69309914
#   Epoch 38/100
# Training loss:  0.6925053
#   Epoch 39/100
# Training loss:  0.6924217
#   Epoch 40/100
# Training loss:  0.6918797
#   Epoch 41/100
# Training loss:  0.6926201
#   Epoch 42/100
# Training loss:  0.6932581
#   Epoch 43/100
# Training loss:  0.6927859
#   Epoch 44/100
# Training loss:  0.688873
#   Epoch 45/100
# Training loss:  0.68650174
#   Epoch 46/100
# Training loss:  0.6878509
#   Epoch 47/100
# Training loss:  0.6883047
#   Epoch 48/100
# Training loss:  0.6867868
#   Epoch 49/100
# Training loss:  0.68335664
#   Epoch 50/100
# Training loss:  0.68321687
#   Epoch 51/100
# Training loss:  0.6828351
#   Epoch 52/100
# Training loss:  0.6811632
#   Epoch 53/100
# Training loss:  0.6800922
#   Epoch 54/100
# Training loss:  0.67831755
#   Epoch 55/100
# Training loss:  0.6776669
#   Epoch 56/100
# Training loss:  0.6781141
#   Epoch 57/100
# Training loss:  0.6775282
#   Epoch 58/100
# Training loss:  0.6750949
#   Epoch 59/100
# Training loss:  0.67409855
#   Epoch 60/100
# Training loss:  0.6757716
#   Epoch 61/100
# Training loss:  0.6759458
#   Epoch 62/100
# Training loss:  0.6707612
#   Epoch 63/100
# Training loss:  0.67143697
#   Epoch 64/100
# Training loss:  0.67089945
#   Epoch 65/100
# Training loss:  0.67107487
#   Epoch 66/100
# Training loss:  0.66998696
#   Epoch 67/100
# Training loss:  0.6788036
#   Epoch 68/100
# Training loss:  0.6905019
#   Epoch 69/100
# Training loss:  0.6816624
#   Epoch 70/100
# Training loss:  0.6778243
#   Epoch 71/100
# Training loss:  0.67923415
#   Epoch 72/100
# Training loss:  0.6740333
#   Epoch 73/100
# Training loss:  0.6709679
#   Epoch 74/100
# Training loss:  0.6758338
#   Epoch 75/100
# Training loss:  0.66865563
#   Epoch 76/100
# Training loss:  0.6686617
#   Epoch 77/100
# Training loss:  0.6686445
#   Epoch 78/100
# Training loss:  0.66365176
#   Epoch 79/100
# Training loss:  0.66466916
#   Epoch 80/100
# Training loss:  0.6622938
#   Epoch 81/100
# Training loss:  0.6603385
#   Epoch 82/100
# Training loss:  0.6596704
#   Epoch 83/100
# Training loss:  0.6601647
#   Epoch 84/100
# Training loss:  0.6611943
#   Epoch 85/100
# Training loss:  0.6581985
#   Epoch 86/100
# Training loss:  0.6583352
#   Epoch 87/100
# Training loss:  0.6562702
#   Epoch 88/100
# Training loss:  0.65593827
#   Epoch 89/100
# Training loss:  0.65607995
#   Epoch 90/100
# Training loss:  0.65351653
#   Epoch 91/100
# Training loss:  0.65573
#   Epoch 92/100
# Training loss:  0.6595867
#   Epoch 93/100
# Training loss:  0.660907
#   Epoch 94/100
# Training loss:  0.6543751
#   Epoch 95/100
# Training loss:  0.65237707
#   Epoch 96/100
# Training loss:  0.65365237
#   Epoch 97/100
# Training loss:  0.6551123
#   Epoch 98/100
# Training loss:  0.64948684
#   Epoch 99/100
# Training loss:  0.6503511
#   Epoch 100/100
# Training loss:  0.651116
# Elapsed time:  586.9914307800009
# Text(0.5, 0, 'epoch')

# %%
# l=[]
# for time, snapshot in enumerate(train_dataset):
#     l.append(snapshot.y.tolist())

# %%
# transposed = list(zip(*l))

# # Trasformarla in liste
# transposed = [list(tup) for tup in transposed]

# %%
# for i in range(24):
#     plt.plot(transposed[i])
#     plt.show()

# %%
# plt.plot(l)
# plt.legend()

# %%
#mu

# %%
#sigma

# %%
'''
# Plot dei risultati del training
plt.figure(figsize=(10, 6))

# Visualizzazione degli output e dei target
plt.subplot(6,4)
plt.plot(outputs[-1][0], label="Model output")  # Ultimo output generato dal modello
plt.plot(targets[-1][0], label="Target")  # Target corrispondenti
plt.xlabel("Time step")
plt.ylabel("Value")
plt.legend()

#plt.tight_layout()
plt.show()
'''
# Out:
# '\n# Plot dei risultati del training\nplt.figure(figsize=(10, 6))\n\n# Visualizzazione degli output e dei target\nplt.subplot(6,4)\nplt.plot(outputs[-1][0], label="Model output")  # Ultimo output generato dal modello\nplt.plot(targets[-1][0], label="Target")  # Target corrispondenti\nplt.xlabel("Time step")\nplt.ylabel("Value")\nplt.legend()\n\n#plt.tight_layout()\nplt.show()\n'

# %%
outputs_hourly = []
targets_hourly = []
for j in range(24):
    outhourlist = [outputs[-1][i][j] for i in range(len(outputs[-1]))]
    tarhourlist = [targets[-1][i][j] for i in range(len(outputs[-1]))]
    outputs_hourly.append(outhourlist)
    targets_hourly.append(tarhourlist)

# %%
#Test set
test_outputs = []  #
test_targets = []  #
for time_step, snapshot in enumerate(test_dataset):
    #snapshot.to('cuda')
    output, H = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr, H=H)
    test_output = descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale)
    test_snapshot = descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale)
    test_outputs.append(test_output)  #
    test_targets.append(test_snapshot)   #

# %%
outputs_hourly_test = []
targets_hourly_test = []
for j in range(24):
    outhourlist = [test_outputs[i][j] for i in range(len(test_outputs))]
    tarhourlist = [test_targets[i][j] for i in range(len(test_outputs))]
    outputs_hourly_test.append(outhourlist)
    targets_hourly_test.append(tarhourlist)

# %%
mse_test = []
for j in range(24):
    sqdiff = [(a - b)**2 for a, b in zip(targets_hourly_test[j], outputs_hourly_test[j])]
    mse_test.append(np.mean(sqdiff))
mse_test
# Out:
# [910.4485895831076,
#  466.8889211810134,
#  225.6222410734054,
#  364.6710533310857,
#  487.3365634288144,
#  1146.15739289685,
#  3942.95903208303,
#  5600.607451365645,
#  6854.428956959574,
#  8906.701080093408,
#  12254.569193380825,
#  13812.737029071128,
#  11760.54030186443,
#  15110.721355875025,
#  15771.062745490386,
#  17118.41041635454,
#  22567.33189698188,
#  24847.9719666726,
#  17373.514383749978,
#  12889.159161436612,
#  8472.540988757928,
#  4762.633591037543,
#  2190.9699551016984,
#  1632.4053244598854]

# %%
#unisco train e test
outputs_merged = [l1 + l2 for l1, l2 in zip(outputs_hourly, outputs_hourly_test)]
targets_merged = [l1 + l2 for l1, l2 in zip(targets_hourly, targets_hourly_test)]

# %%
list_ids = loader._node_ids
dict = list_ids.item()
inverse_dict = {value: key for key, value in dict.items()}
inverse_dict.get(0)
# Out:
# '00:00'

# %%
fig, axs = plt.subplots(6, 4, figsize=(11, 10), sharey=True, sharex=True)

# Iteriamo sulla lista delle matrici e le visualizziamo in subplots
for i in range(6):
    axs[i,0].plot(targets_merged[i*4], label="Ground Truth")
    axs[i,0].plot(outputs_merged[i*4], label=name_model)
    axs[i,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,1].plot(targets_merged[i*4+1], label="Ground Truth")
    axs[i,1].plot(outputs_merged[i*4+1], label=name_model)
    axs[i,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,2].plot(targets_merged[i*4+2], label="Ground Truth")
    axs[i,2].plot(outputs_merged[i*4+2], label=name_model)
    axs[i,2].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,3].plot(targets_merged[i*4+3], label="Ground Truth")
    axs[i,3].plot(outputs_merged[i*4+3], label=name_model)
    axs[i,3].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,0].set_title(inverse_dict[i*4])  # Titolo del subplot
    axs[i,1].set_title(inverse_dict[i*4+1])
    axs[i,2].set_title(inverse_dict[i*4+2])
    axs[i,3].set_title(inverse_dict[i*4+3])
    #axs[i].axis('off')  # Nasconde gli assi
plt.legend()
plt.savefig('plot/'+name_model.lower()+'plot.jpg', format='jpg')
# Mostriamo la figura con tutti i subplot
plt.show()

# %%
hour = 3

diff = [a - b for a, b in zip(targets_merged[j], outputs_merged[j])]
fig, axs = plt.subplots(2, 1, figsize=(9, 8))
axs[0].plot(targets_merged[hour], label="Ground Truth")
axs[0].plot(outputs_merged[hour], label=name_model)
axs[0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0].legend()
axs[0].set_title("Daily series at "+inverse_dict[hour])
axs[1].plot(diff, label="Residual")
axs[1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1].legend()
axs[1].set_title("Residuals")
plt.show()

# %%
hour = 3

diff = [a - b for a, b in zip(targets_hourly_test[j], outputs_hourly_test[j])]
fig, axs = plt.subplots(2, 1, figsize=(9, 8))
axs[0].plot(targets_hourly_test[hour][:1000], label="Ground Truth")
axs[0].plot(outputs_hourly_test[hour][:1000], label=name_model)
axs[0].legend()
axs[0].set_title("Daily series at "+inverse_dict[hour]+" in the test set")
axs[1].plot(diff[:1000], label="Residual")
axs[1].legend()
axs[1].set_title("Residuals")
plt.show()

# %%
hour1 = 2
hour2 = 16

diff1 = [a - b for a, b in zip(targets_merged[hour1], outputs_merged[hour1])]
diff2 = [a - b for a, b in zip(targets_merged[hour2], outputs_merged[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_merged[hour1], label="Ground Truth")
axs[0,0].plot(outputs_merged[hour1], label=name_model)
axs[0,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0,0].legend()
axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1])
axs[1,0].plot(diff1, label="Residual")
axs[1,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1,0].legend()
axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_merged[hour2], label="Ground Truth")
axs[0,1].plot(outputs_merged[hour2], label=name_model)
axs[0,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0,1].legend()
axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2])
axs[1,1].plot(diff2, label="Residual")
axs[1,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1,1].legend()
axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('plot/focus'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
hour1 = 2
hour2 = 16
fd=500

diff1 = [a - b for a, b in zip(targets_hourly_test[hour1], outputs_hourly_test[hour1])]
diff2 = [a - b for a, b in zip(targets_hourly_test[hour2], outputs_hourly_test[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_hourly_test[hour1][:fd], label="Ground Truth")
axs[0,0].plot(outputs_hourly_test[hour1][:fd], label=name_model)
axs[0,0].legend()
#axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1]+" in first "+str(fd)+" days of the test set")
axs[1,0].plot(diff1[:fd], label="Residual")
axs[1,0].legend()
#axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_hourly_test[hour2][:fd], label="Ground Truth")
axs[0,1].plot(outputs_hourly_test[hour2][:fd], label=name_model)
axs[0,1].legend()
#axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2]+" in first "+str(fd)+" days of the test set")
axs[1,1].plot(diff2[:fd], label="Residual")
axs[1,1].legend()
#axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('plot/focustest'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
hour1 = 2
hour2 = 16
fd=100

diff1 = [a - b for a, b in zip(targets_hourly_test[hour1], outputs_hourly_test[hour1])]
diff2 = [a - b for a, b in zip(targets_hourly_test[hour2], outputs_hourly_test[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_hourly_test[hour1][-fd:], label="Ground Truth")
axs[0,0].plot(outputs_hourly_test[hour1][-fd:], label=name_model)
axs[0,0].legend()
#axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1]+" in last "+str(fd)+" days of the test set")
axs[1,0].plot(diff1[:fd], label="Residual")
axs[1,0].legend()
#axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_hourly_test[hour2][-fd:], label="Ground Truth")
axs[0,1].plot(outputs_hourly_test[hour2][-fd:], label=name_model)
axs[0,1].legend()
#axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2]+" in last "+str(fd)+" days of the test set")
axs[1,1].plot(diff2[:fd], label="Residual")
axs[1,1].legend()
#axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('plot/focustest'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
mse_train = []
for j in range(24):
    sqdiff = [(a - b)**2 for a, b in zip(targets_hourly[j], outputs_hourly[j])]
    mse_train.append(np.mean(sqdiff))
mse_train
# Out:
# [846.8130274081797,
#  648.9927067330832,
#  346.9756811054153,
#  280.21085665444537,
#  352.169599025144,
#  537.2692159394941,
#  3580.5963893862922,
#  4259.965012822269,
#  5792.784468846285,
#  7534.7242971530395,
#  10832.013744370452,
#  14245.28422815649,
#  14669.415879701592,
#  16302.891428014256,
#  17098.42965648832,
#  17395.73204766649,
#  20389.74905727761,
#  26615.04163807519,
#  16559.2161189118,
#  12351.861903728206,
#  9462.526171288444,
#  7684.04550753368,
#  2155.6871398703556,
#  1864.1537169368116]

# %%
import torch
torch.cuda.is_available()
# Out:
# /opt/tljh/user/envs/py312_geomtemp_090624/lib/python3.12/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /opt/conda/conda-bld/pytorch_1704987289929/work/c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# False

# %%
#########################
mse_train_prunedTGCN = mse_train
mse_test_prunedTGCN = mse_test

# %%
mse_train_prunedTGCN = [round(v, 1) for v in mse_train_prunedTGCN]

# %%
import pandas as pd
df_mse = pd.DataFrame({'a': mse_train_DCRNN, 'b': mse_test_DCRNN, 'c': mse_train_GConvGRU, 'd': mse_test_GConvGRU, 'e': mse_train_TGCN, 'f': mse_test_TGCN, 'g': mse_train_prunedTGCN, 'h': mse_test_prunedTGCN})

# Esportare la tabella in formato LaTeX
latex_table = df_mse.to_latex(index=False)
print(latex_table)

# %%
# Per salvare modello
#model = model.to('cpu')
# torch.save(model.state_dict(), 'models/gnn_'+name_model+'_3_0.05.pth')

# %%
# Per caricare modello
model = RecurrentGCN(node_features = lags)
model.load_state_dict(torch.load('models/gnn_TGCN_3_0.05.pth'))
#model = model.to('cuda')
print(model)
# Out:
# RecurrentGCN(
#   (recurrent): TGCN(
#     (conv_z): GCNConv(3, 30)
#     (linear_z): Linear(in_features=60, out_features=30, bias=True)
#     (conv_r): GCNConv(3, 30)
#     (linear_r): Linear(in_features=60, out_features=30, bias=True)
#     (conv_h): GCNConv(3, 30)
#     (linear_h): Linear(in_features=60, out_features=30, bias=True)
#   )
#   (linear): Linear(in_features=30, out_features=1, bias=True)
# )

# %%
#Training set
H = torch.zeros(24,out_channels)
outputs = []  #
targets = []  #
for time_step, snapshot in enumerate(train_dataset):
    #snapshot.to('cuda')
    output, H = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr, H=H)
    train_output = descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale)
    train_snapshot = descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale)
    outputs.append(train_output)  #
    targets.append(train_snapshot)   #

# %%
outputs_hourly = []
targets_hourly = []
for j in range(24):
    outhourlist = [outputs[i][j] for i in range(len(outputs))]
    tarhourlist = [targets[i][j] for i in range(len(outputs))]
    outputs_hourly.append(outhourlist)
    targets_hourly.append(tarhourlist)
