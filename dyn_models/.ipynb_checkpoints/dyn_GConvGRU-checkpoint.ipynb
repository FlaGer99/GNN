# %%
import json
import numpy as np
from torch_geometric_temporal.signal import DynamicGraphTemporalSignal
import torch
import time


class MyDynamicDatasetLoader(object):
    def __init__(self):
        self._read_web_data()

    def _read_web_data(self):
        with open('../data/graphs/grafo_corr_sliding0.4.json') as f:
            self._dataset = json.load(f)

    def _get_edges(self):
        self._edges = []
        for time in self._dataset["time_periods"]:
            self._edges.append(
                np.array(self._dataset["edge_mapping"]["edge_index"][str(time)]).T
            )
        self._edges = self._edges[self.lags-1:]

    def _get_node_ids(self):
        self._node_ids = np.array(self._dataset["node_ids"])
    
    def _get_edge_weights(self):
        self._edge_weights = []
        for time in self._dataset["time_periods"]:
            self._edge_weights.append(
                np.array(self._dataset["edge_mapping"]["edge_weight"][str(time)])
            )
        self._edge_weights = self._edge_weights[self.lags-1:]

    def _get_targets_and_features(self):
        stacked_target = np.array(self._dataset["y"])
        self.scale = []
        for i in range(24):
            self.scale.append(max(stacked_target[:,i]))
        self.scale = np.array(self.scale)
        self.mu = np.mean(stacked_target, axis=0)
        self.sigma = np.std(stacked_target, axis=0)
        standardized_target = (stacked_target - self.mu) / (self.sigma + 10 ** -10)
        #standardized_target = stacked_target/self.scale
        self.features = [
            standardized_target[i : i + self.lags, :].T
            for i in range(len(self._dataset["time_periods"])-self.lags+1)
        ]
        self.targets = [
            standardized_target[i + self.lags, :].T
            for i in range(len(self._dataset["time_periods"])-self.lags+1)
        ]

    def get_dataset(self, lags: int = 4) -> DynamicGraphTemporalSignal:
        """Returning the Wind Speed data iterator.

        Args types:
            * **lags** *(int)* - The number of time lags.
        Return types:
            * **dataset** *(StaticGraphTemporalSignal)* - The Wind Speed dataset.
        """
        self.lags = lags
        self._get_edges()
        self._get_edge_weights()
        self._get_node_ids()
        self._get_targets_and_features()
        dataset = DynamicGraphTemporalSignal(
            self._edges, self._edge_weights, self.features, self.targets
        )
        print(self._dataset["time_periods"][0])
        return dataset

# %%
lags = 3
out_channels = 10
loader = MyDynamicDatasetLoader()
dataset = loader.get_dataset(lags=lags)
dataset[2]
# Out:
# 03/31/2000
# Data(x=[24, 3], edge_index=[2, 334], edge_attr=[334], y=[24])

# %%
#descale(dataset[0].y.detach().cpu().numpy(), sigma, mu, scale)#[:,0]

# %%
import torch.nn.functional as F
from matplotlib import pyplot as plt
from torch_geometric_temporal.nn.recurrent import GConvGRU, TGCN, GConvLSTM
from torch_geometric_temporal.signal import temporal_signal_split

train_dataset, test_dataset = temporal_signal_split(dataset, train_ratio=0.8)

# %%
# train_dataset[0].edge_attr

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from updated_models.GConvGRU_w import GConvGRU_W
from updated_models.RecGRU import RecGRU_W
from updated_models.RecGRU_w import RecGRU_W_up

# %%
#descale(train_dataset[6349].y.detach().cpu().numpy(), sigma, mu, scale)#[:,2]

# %%
#descale(test_dataset[1587].y.detach().cpu().numpy(), sigma, mu, scale)#[:,2]

# %%
class GNN(torch.nn.Module):
    def __init__(self, node_features):
        super(GNN, self).__init__()
        self.recurrent = GConvGRU_W(in_channels=node_features, out_channels=out_channels, num_stacks=3, num_layers=3, act='relu')
        #self.recurrent = RecGRU_W_up(in_channels=node_features, num_stacks=1, toll=1, act='tanh')#num_layers=3)#out_channels=out_channels,
        self.linear = torch.nn.Linear(out_channels, 1)#node_features

    def forward(self, x, edge_index, edge_weight, H):
        H = self.recurrent(x, edge_index, edge_weight, H)
        h = H
        #h = F.relu(h)
        h = self.linear(h)
        return h,H

# %%
model = GNN(node_features = lags)
name_model = model.recurrent.__class__.__name__.split('_')[0]
name_model
# Out:
# 'GConvGRU'

# %%
name_model = 'ChebConvGRU'

# %%
sigma = loader.sigma
mu = loader.mu
scale = loader.scale
def descale(output, sigma, mu, scale):
    return output*sigma + mu#scale

# %%
#model = model.to('cuda')
model.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = F.mse_loss

start_time = time.perf_counter() # Start timer
num_epochs = 200
losses = []
outputs = []  #
targets = []  #
for epoch in range(num_epochs):
    loss = 0
    epoch_outputs = []  #
    epoch_targets = []  #
    H = torch.zeros(24,out_channels)#lags
    print("  Epoch %d/%d" % (epoch+1,num_epochs))
    for time_step, snapshot in enumerate(train_dataset):
        #snapshot.to('cuda')
        output, H = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr, H=H)
        loss = loss + loss_fn(output.T[0], snapshot.y)
        epoch_outputs.append(descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale))  #
        epoch_targets.append(descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale))   #

        # if torch.isnan(output).any():
        #     print(time_step)
    
    loss = loss/(time_step+1)
    
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    losses.append(loss.cpu().detach().numpy())
    outputs.append(epoch_outputs)  #
    targets.append(epoch_targets)  #
    print('Training loss: ', losses[-1])

end_time = time.perf_counter() # End timer
print("Elapsed time: ", end_time - start_time) # Calculate elapsed time

plt.plot(losses)
plt.xlabel("epoch")
# Out:
#   Epoch 1/200
# /opt/tljh/user/envs/py312_geomtemp_090624/lib/python3.12/site-packages/torch/autograd/__init__.py:266: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /opt/conda/conda-bld/pytorch_1704987289929/work/c10/cuda/CUDAFunctions.cpp:108.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Training loss:  1.1161357
#   Epoch 2/200
# Training loss:  0.9618189
#   Epoch 3/200
# Training loss:  0.882747
#   Epoch 4/200
# Training loss:  0.8404638
#   Epoch 5/200
# Training loss:  0.8160583
#   Epoch 6/200
# Training loss:  0.798965
#   Epoch 7/200
# Training loss:  0.788975
#   Epoch 8/200
# Training loss:  0.7834679
#   Epoch 9/200
# Training loss:  0.77670145
#   Epoch 10/200
# Training loss:  0.7455313
#   Epoch 16/200
# Training loss:  0.7415679
#   Epoch 17/200
# Training loss:  0.736386
#   Epoch 18/200
# Training loss:  0.7313849
#   Epoch 19/200
# Training loss:  0.7276026
#   Epoch 20/200
# Training loss:  0.723921
#   Epoch 21/200
# Training loss:  0.7201369
#   Epoch 22/200
# Training loss:  0.716729
#   Epoch 23/200
# Training loss:  0.7147196
#   Epoch 24/200
# Training loss:  0.71308047
#   Epoch 25/200
# Training loss:  0.71111
#   Epoch 26/200
# Training loss:  0.70914316
#   Epoch 27/200
# Training loss:  0.7073274
#   Epoch 28/200
# Training loss:  0.70527637
#   Epoch 29/200
# Training loss:  0.70314693
#   Epoch 30/200
# Training loss:  0.7012552
#   Epoch 31/200
# Training loss:  0.69958794
#   Epoch 32/200
# Training loss:  0.6981317
#   Epoch 33/200
# Training loss:  0.69709754
#   Epoch 34/200
# Training loss:  0.69760567
#   Epoch 35/200
# Training loss:  0.6981015
#   Epoch 36/200
# Training loss:  0.695093
#   Epoch 37/200
# Training loss:  0.6928833
#   Epoch 38/200
# Training loss:  0.693374
#   Epoch 39/200
# Training loss:  0.6900282
#   Epoch 40/200
# Training loss:  0.6905095
#   Epoch 41/200
# Training loss:  0.6874168
#   Epoch 42/200
# Training loss:  0.68770206
#   Epoch 43/200
# Training loss:  0.6854928
#   Epoch 44/200
# Training loss:  0.68435144
#   Epoch 45/200
# Training loss:  0.68362606
#   Epoch 46/200
# Training loss:  0.6817767
#   Epoch 47/200
# Training loss:  0.68175656
#   Epoch 48/200
# Training loss:  0.6800483
#   Epoch 49/200
# Training loss:  0.6800087
#   Epoch 50/200
# Training loss:  0.6784388
#   Epoch 51/200
# Training loss:  0.67821157
#   Epoch 52/200
# Training loss:  0.67709756
#   Epoch 53/200
# Training loss:  0.67640674
#   Epoch 54/200
# Training loss:  0.67587394
#   Epoch 55/200
# Training loss:  0.6747634
#   Epoch 56/200
# Training loss:  0.67440367
#   Epoch 57/200
# Training loss:  0.67324513
#   Epoch 58/200
# Training loss:  0.6726405
#   Epoch 59/200
# Training loss:  0.67214745
#   Epoch 60/200
# Training loss:  0.67115587
#   Epoch 61/200
# Training loss:  0.6706625
#   Epoch 62/200
# Training loss:  0.6701931
#   Epoch 63/200
# Training loss:  0.66938066
#   Epoch 64/200
# Training loss:  0.66879255
#   Epoch 65/200
# Training loss:  0.668477
#   Epoch 66/200
# Training loss:  0.66792333
#   Epoch 67/200
# Training loss:  0.6671656
#   Epoch 68/200
# Training loss:  0.66670084
#   Epoch 69/200
# Training loss:  0.6663265
#   Epoch 70/200
# Training loss:  0.66574985
#   Epoch 71/200
# Training loss:  0.66515404
#   Epoch 72/200
# Training loss:  0.66455007
#   Epoch 73/200
# Training loss:  0.664055
#   Epoch 74/200
# Training loss:  0.66364974
#   Epoch 75/200
# Training loss:  0.6632778
#   Epoch 76/200
# Training loss:  0.66304237
#   Epoch 77/200
# Training loss:  0.662581
#   Epoch 78/200
# Training loss:  0.6620494
#   Epoch 79/200
# Training loss:  0.66106606
#   Epoch 80/200
# Training loss:  0.6602092
#   Epoch 81/200
# Training loss:  0.6595374
#   Epoch 82/200
# Training loss:  0.6590932
#   Epoch 83/200
# Training loss:  0.6589107
#   Epoch 84/200
# Training loss:  0.65893793
#   Epoch 85/200
# Training loss:  0.65979254
#   Epoch 86/200
# Training loss:  0.6587161
#   Epoch 87/200
# Training loss:  0.6570723
#   Epoch 88/200
# Training loss:  0.6559346
#   Epoch 89/200
# Training loss:  0.6566507
#   Epoch 90/200
# Training loss:  0.656167
#   Epoch 91/200
# Training loss:  0.6547749
#   Epoch 92/200
# Training loss:  0.6542232
#   Epoch 93/200
# Training loss:  0.6535086
#   Epoch 94/200
# Training loss:  0.65363026
#   Epoch 95/200
# Training loss:  0.6538871
#   Epoch 96/200
# Training loss:  0.6519833
#   Epoch 97/200
# Training loss:  0.6511432
#   Epoch 98/200
# Training loss:  0.6514496
#   Epoch 99/200
# Training loss:  0.6500394
#   Epoch 100/200
# Training loss:  0.64996547
#   Epoch 101/200
# Training loss:  0.64999664
#   Epoch 102/200
# Training loss:  0.64744717
#   Epoch 103/200
# Training loss:  0.6487374
#   Epoch 104/200
# Training loss:  0.6491651
#   Epoch 105/200
# Training loss:  0.6468787
#   Epoch 106/200
# Training loss:  0.65090597
#   Epoch 107/200
# Training loss:  0.6522677
#   Epoch 108/200
# Training loss:  0.6520496
#   Epoch 109/200
# Training loss:  0.64575344
#   Epoch 110/200
# Training loss:  0.6478647
#   Epoch 111/200
# Training loss:  0.6464333
#   Epoch 112/200
# Training loss:  0.64439154
#   Epoch 113/200
# Training loss:  0.6443994
#   Epoch 114/200
# Training loss:  0.6433912
#   Epoch 115/200
# Training loss:  0.64217997
#   Epoch 116/200
# Training loss:  0.64236116
#   Epoch 117/200
# Training loss:  0.64122504
#   Epoch 118/200
# Training loss:  0.6396441
#   Epoch 119/200
# Training loss:  0.6392721
#   Epoch 120/200
# Training loss:  0.63897514
#   Epoch 121/200
# Training loss:  0.63864255
#   Epoch 122/200
# Training loss:  0.64011145
#   Epoch 123/200
# Training loss:  0.639032
#   Epoch 124/200
# Training loss:  0.63490844
#   Epoch 125/200
# Training loss:  0.6367956
#   Epoch 126/200
# Training loss:  0.63840914
#   Epoch 127/200
# Training loss:  0.6392061
#   Epoch 128/200
# Training loss:  0.6344094
#   Epoch 129/200
# Training loss:  0.6339545
#   Epoch 130/200
# Training loss:  0.6368832
#   Epoch 131/200
# Training loss:  0.636509
#   Epoch 132/200
# Training loss:  0.63107747
#   Epoch 133/200
# Training loss:  0.63240564
#   Epoch 134/200
# Training loss:  0.63202584
#   Epoch 135/200
# Training loss:  0.6293556
#   Epoch 136/200
# Training loss:  0.62966293
#   Epoch 137/200
# Training loss:  0.63069946
#   Epoch 138/200
# Training loss:  0.62795085
#   Epoch 139/200
# Training loss:  0.6255474
#   Epoch 140/200
# Training loss:  0.626871
#   Epoch 141/200
# Training loss:  0.62572163
#   Epoch 142/200
# Training loss:  0.6247583
#   Epoch 143/200
# Training loss:  0.6235367
#   Epoch 144/200
# Training loss:  0.6220203
#   Epoch 145/200
# Training loss:  0.6244341
#   Epoch 146/200
# Training loss:  0.6234021
#   Epoch 147/200
# Training loss:  0.6257598
#   Epoch 148/200
# Training loss:  0.62586606
#   Epoch 149/200
# Training loss:  0.6239025
#   Epoch 150/200
# Training loss:  0.6240362
#   Epoch 151/200
# Training loss:  0.62046796
#   Epoch 152/200
# Training loss:  0.6213018
#   Epoch 153/200
# Training loss:  0.62017566
#   Epoch 154/200
# Training loss:  0.62255776
#   Epoch 155/200
# Training loss:  0.61643064
#   Epoch 156/200
# Training loss:  0.6203445
#   Epoch 157/200
# Training loss:  0.619411
#   Epoch 158/200
# Training loss:  0.6201386
#   Epoch 159/200
# Training loss:  0.61807555
#   Epoch 160/200
# Training loss:  0.61877763
#   Epoch 161/200
# Training loss:  0.61596143
#   Epoch 162/200
# Training loss:  0.61663985
#   Epoch 163/200
# Training loss:  0.62058115
#   Epoch 164/200
# Training loss:  0.6132146
#   Epoch 165/200
# Training loss:  0.61431545
#   Epoch 166/200
# Training loss:  0.61303926
#   Epoch 167/200
# Training loss:  0.61271805
#   Epoch 168/200
# Training loss:  0.61130726
#   Epoch 169/200
# Training loss:  0.61352336
#   Epoch 170/200
# Training loss:  0.61072236
#   Epoch 171/200
# Training loss:  0.60885245
#   Epoch 172/200
# Training loss:  0.6067927
#   Epoch 173/200
# Training loss:  0.6096636
#   Epoch 174/200
# Training loss:  0.6114298
#   Epoch 175/200
# Training loss:  0.6096365
#   Epoch 176/200
# Training loss:  0.6133892
#   Epoch 177/200
# Training loss:  0.613746
#   Epoch 178/200
# Training loss:  0.6121219
#   Epoch 179/200
# Training loss:  0.6109819
#   Epoch 180/200
# Training loss:  0.61507714
#   Epoch 181/200
# Training loss:  0.6181038
#   Epoch 182/200
# Training loss:  0.61574566
#   Epoch 183/200
# Training loss:  0.6124408
#   Epoch 184/200
# Training loss:  0.6138843
#   Epoch 185/200
# Training loss:  0.6167869
#   Epoch 186/200
# Training loss:  0.61437994
#   Epoch 187/200
# Training loss:  0.61969215
#   Epoch 188/200
# Training loss:  0.6126769
#   Epoch 189/200
# Training loss:  0.613836
#   Epoch 190/200
# Training loss:  0.6091955
#   Epoch 191/200
# Training loss:  0.61359143
#   Epoch 192/200
# Training loss:  0.6107322
#   Epoch 193/200
# Training loss:  0.6138444
#   Epoch 194/200
# Training loss:  0.60890955
#   Epoch 195/200
# Training loss:  0.6061441
#   Epoch 196/200
# Training loss:  0.60679317
#   Epoch 197/200
# Training loss:  0.60429686
#   Epoch 198/200
# Training loss:  0.6032267
#   Epoch 199/200
# Training loss:  0.6018882
#   Epoch 200/200
# Training loss:  0.6001535
# Elapsed time:  5274.667867823002
# Text(0.5, 0, 'epoch')

# %%
model.recurrent.conv_q_z.lins[0].weight.shape
# Out:
# torch.Size([10, 10])

# %%
epoch
# Out:
# 115

# %%
plt.plot(losses)

# %%
# a=model(snapshot.x, snapshot.edge_index, snapshot.edge_attr)
# print(a)
# Out:
# torch.Size([24, 3])

# %%
# print(epoch_outputs.append(descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale)))
# print(epoch_targets.append(descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale)))

# %%
for name, p in model.named_parameters():
    print(name)
    print(p.numel())
print('-------')
tot = sum(p.numel() for p in model.parameters())
print('total parameters = '+str(tot))
# Out:
# recurrent.w_q_z
# 100
# recurrent.w_x_z
# 100
# recurrent.b_z
# 240
# recurrent.w_q_r
# 100
# recurrent.w_x_r
# 100
# recurrent.b_r
# 240
# recurrent.w_q_h
# 100
# recurrent.w_x_h
# 100
# recurrent.b_h
# 240
# recurrent.conv_x_z.weight
# 200
# recurrent.conv_x_z.init_weight
# 30
# recurrent.conv_x_z.bias
# 720
# recurrent.conv_x_z.lins.0.weight
# 30
# recurrent.conv_x_z.lins.1.weight
# 30
# recurrent.conv_x_z.lins.2.weight
# 30
# recurrent.conv_x_z.lin_o.weight
# 30
# recurrent.conv_q_z.weight
# 200
# recurrent.conv_q_z.init_weight
# 100
# recurrent.conv_q_z.bias
# 720
# recurrent.conv_q_z.lins.0.weight
# 100
# recurrent.conv_q_z.lins.1.weight
# 100
# recurrent.conv_q_z.lins.2.weight
# 100
# recurrent.conv_q_z.lin_o.weight
# 100
# recurrent.conv_x_r.weight
# 200
# recurrent.conv_x_r.init_weight
# 30
# recurrent.conv_x_r.bias
# 720
# recurrent.conv_x_r.lins.0.weight
# 30
# recurrent.conv_x_r.lins.1.weight
# 30
# recurrent.conv_x_r.lins.2.weight
# 30
# recurrent.conv_x_r.lin_o.weight
# 30
# recurrent.conv_q_r.weight
# 200
# recurrent.conv_q_r.init_weight
# 100
# recurrent.conv_q_r.bias
# 720
# recurrent.conv_q_r.lins.0.weight
# 100
# recurrent.conv_q_r.lins.1.weight
# 100
# recurrent.conv_q_r.lins.2.weight
# 100
# recurrent.conv_q_r.lin_o.weight
# 100
# recurrent.conv_x_h.weight
# 200
# recurrent.conv_x_h.init_weight
# 30
# recurrent.conv_x_h.bias
# 720
# recurrent.conv_x_h.lins.0.weight
# 30
# recurrent.conv_x_h.lins.1.weight
# 30
# recurrent.conv_x_h.lins.2.weight
# 30
# recurrent.conv_x_h.lin_o.weight
# 30
# recurrent.conv_q_h.weight
# 200
# recurrent.conv_q_h.init_weight
# 100
# recurrent.conv_q_h.bias
# 720
# recurrent.conv_q_h.lins.0.weight
# 100
# recurrent.conv_q_h.lins.1.weight
# 100
# recurrent.conv_q_h.lins.2.weight
# 100
# recurrent.conv_q_h.lin_o.weight
# 100
# linear.weight
# 10
# linear.bias
# 1
# -------
# total parameters = 8801

# %%
# sum_list_xz = []
# num_epochs = 200
# for j in range(num_epochs):
#     sum_t = 0
#     for t in model.recurrent.conv_x_z.list_t[6349*j:6349*(j+1)]:
#         sum_t = t + sum_t
#         if t > 501:
#             print(str(t)+' - '+str(j+1))
#         if t < 2:
#             print(str(t)+' - '+str(j+1))
#     sum_list_xz.append(sum_t/6350)

# %%
# sum_list_hz = []
# for j in range(num_epochs):
#     sum_t = 0
#     for t in model.recurrent.conv_h_z.list_t[6349*j:6349*(j+1)]:
#         sum_t = t + sum_t
#         if t > 501:
#             print(str(t)+' - '+str(j+1))
#         if t < 2 & j > 0:
#             print(str(t)+' - '+str(j+1))
#     sum_list_hz.append(sum_t/6350)

# %%
# sum_list_xr = []
# for j in range(num_epochs):
#     sum_t = 0
#     for t in model.recurrent.conv_x_r.list_t[6349*j:6349*(j+1)]:
#         sum_t = t + sum_t
#         if t > 501:
#             print(str(t)+' - '+str(j+1))
#         if t < 2:
#             print(str(t)+' - '+str(j+1))
#     sum_list_xr.append(sum_t/6350)

# %%
# sum_list_hr = []
# for j in range(num_epochs):
#     sum_t = 0
#     for t in model.recurrent.conv_h_r.list_t[6349*j:6349*(j+1)]:
#         sum_t = t + sum_t
#         if t > 501:
#             print(str(t)+' - '+str(j+1))
#         if t < 2 & j > 0:
#             print(str(t)+' - '+str(j+1))
#     sum_list_hr.append(sum_t/6350)

# %%
# sum_list_xh = []
# for j in range(num_epochs):
#     sum_t = 0
#     for t in model.recurrent.conv_x_h.list_t[6349*j:6349*(j+1)]:
#         sum_t = t + sum_t
#         if t > 501:
#             print(str(t)+' - '+str(j+1))
#         if t < 2:
#             print(str(t)+' - '+str(j+1))
#     sum_list_xh.append(sum_t/6350)

# %%
# sum_list_hh = []
# for j in range(num_epochs):
#     sum_t = 0
#     for t in model.recurrent.conv_h_h.list_t[6349*j:6349*(j+1)]:
#         sum_t = t + sum_t
#         if t > 501:
#             print(str(t)+' - '+str(j+1))
#         if t < 2 & j > 0:
#             print(str(t)+' - '+str(j+1))
#     sum_list_hh.append(sum_t/6350)

# %%
# plt.plot(sum_list_xz, label='update_x')
# plt.plot(sum_list_hz, label='update_q')
# plt.plot(sum_list_xr, label='reset_x')
# plt.plot(sum_list_hr, label='reset_q')
# plt.plot(sum_list_xh, label='candidate_x')
# plt.plot(sum_list_hh, label='candidate_q')
# plt.legend()

# %%
outputs_hourly = []
targets_hourly = []
for j in range(24):
    outhourlist = [outputs[-1][i][j] for i in range(len(outputs[-1]))]
    tarhourlist = [targets[-1][i][j] for i in range(len(outputs[-1]))]
    outputs_hourly.append(outhourlist)
    targets_hourly.append(tarhourlist)

# %%
#Test set
test_outputs = []  #
test_targets = []  #
for time_step, snapshot in enumerate(test_dataset):
    #snapshot.to('cuda')
    output, H = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr, H)
    test_output = descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale)
    test_snapshot = descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale)
    test_outputs.append(test_output)  #
    test_targets.append(test_snapshot)   #
#snapshot.x

# %%
outputs_hourly_test = []
targets_hourly_test = []
for j in range(24):
    outhourlist = [test_outputs[i][j] for i in range(len(test_outputs))]
    tarhourlist = [test_targets[i][j] for i in range(len(test_outputs))]
    outputs_hourly_test.append(outhourlist)
    targets_hourly_test.append(tarhourlist)

# %%
mse_test = []
for j in range(24):
    sqdiff = [(a - b)**2 for a, b in zip(targets_hourly_test[j], outputs_hourly_test[j])]
    mse_test.append(np.mean(sqdiff))
mse_test
# Out:
# [843.1821266310538,
#  411.21864931764713,
#  215.04967754745553,
#  372.45298237435435,
#  477.7967794393804,
#  1127.7776382477366,
#  3591.3064093512053,
#  5364.574741563688,
#  6340.157292876294,
#  8453.766143385401,
#  11582.681266689026,
#  13271.049794115605,
#  11775.6329892428,
#  15266.894969852845,
#  14304.694386979354,
#  15261.430521179118,
#  20278.673871159357,
#  23795.488319509725,
#  16336.319339882948,
#  12395.869437668338,
#  8168.601564967232,
#  4221.283307212115,
#  2068.764050799245,
#  1665.258794213151]

# %%
np.mean(mse_test)
# Out:
# 8232.913543925211

# %%
mae_train = []
for j in range(24):
    absdiff = [abs(a - b) for a, b in zip(targets_hourly[j], outputs_hourly[j])]
    mae_train.append(np.mean(absdiff))
mae_train
# Out:
# [11.214657693191754,
#  10.672957550756143,
#  8.752981886431105,
#  8.21233833265946,
#  8.335790318338484,
#  9.502921419571807,
#  21.531994343894038,
#  24.039030376924785,
#  28.967908412198934,
#  34.47423806790332,
#  42.405994284364894,
#  49.172523059760465,
#  47.40843078669302,
#  50.51398472340057,
#  51.093899164197005,
#  52.11439922501472,
#  63.67178135692012,
#  72.7937069438191,
#  52.06895659510788,
#  45.023321666628156,
#  37.62644525284636,
#  36.52039006130905,
#  17.318528842167026,
#  19.106600652021527]

# %%
np.mean(mae_train)
# Out:
# 33.43932420900499

# %%
mse_train = []
for j in range(24):
    sqdiff = [(a - b)**2 for a, b in zip(targets_hourly[j], outputs_hourly[j])]
    mse_train.append(np.mean(sqdiff))
mse_train
# Out:
# [708.2964246039375,
#  560.2499467145466,
#  307.6920963980648,
#  236.26320297984378,
#  288.12581802194643,
#  427.25539226132753,
#  2928.2464249281757,
#  3254.904244909075,
#  4734.972465772621,
#  6218.794226667093,
#  8717.119800684924,
#  11306.527762322215,
#  11262.75543082394,
#  12318.949835370679,
#  12875.102613662772,
#  12953.076710711375,
#  15931.685076729653,
#  20095.968637834194,
#  12466.962088192942,
#  9368.598175989007,
#  7134.287955806619,
#  6281.657857013444,
#  1636.370441577657,
#  1677.8614906026967]

# %%
np.mean(mse_train)
# Out:
# 6820.488505024115

# %%
mae_test = []
for j in range(24):
    absdiff = [abs(a - b) for a, b in zip(targets_hourly_test[j], outputs_hourly_test[j])]
    mae_test.append(np.mean(absdiff))
mae_test
# Out:
# [8.683762702696683,
#  6.9234239148745065,
#  6.49801949439621,
#  6.735151341726139,
#  7.155738790300285,
#  8.891320280167132,
#  19.363927399457285,
#  26.00280203689333,
#  27.649841249664778,
#  36.639062078539766,
#  48.0552835720429,
#  50.62825235261033,
#  47.03930570000249,
#  56.61916116224729,
#  53.01007606197591,
#  55.291216610530626,
#  68.47237213781032,
#  78.63151644646052,
#  59.183825469246834,
#  52.294365231126974,
#  37.616246109494746,
#  25.636142428267863,
#  14.263736097906607,
#  14.184703392197386]

# %%
np.mean(mae_test)
# Out:
# 33.97788550252654

# %%
mse_train_gconv = mse_train
mse_test_gconv = mse_test
mae_train_gconv = mae_train
mae_test_gconv = mae_test

# %%
mse_train_gconv = [round(v, 1) for v in mse_train_gconv]
mse_test_gconv = [round(v, 1) for v in mse_test_gconv]

# %%
mae_train_gconv = [round(v, 3) for v in mae_train_gconv]
mae_test_gconv = [round(v, 3) for v in mae_test_gconv]

# %%
import pandas as pd
df_mse = pd.DataFrame({'a': mse_train_gconv, 'b': mse_test_gconv, 'c': mae_train_gconv, 'd': mae_test_gconv})

# Esportare la tabella in formato LaTeX
latex_table = df_mse.to_latex(index=False)
print(latex_table)
# Out:
# \begin{tabular}{rrrr}
# \toprule
#       a &       b &      c &      d \\
# \midrule
#   708.3 &   843.2 & 11.215 &  8.684 \\
#   560.2 &   411.2 & 10.673 &  6.923 \\
#   307.7 &   215.0 &  8.753 &  6.498 \\
#   236.3 &   372.5 &  8.212 &  6.735 \\
#   288.1 &   477.8 &  8.336 &  7.156 \\
#   427.3 &  1127.8 &  9.503 &  8.891 \\
#  2928.2 &  3591.3 & 21.532 & 19.364 \\
#  3254.9 &  5364.6 & 24.039 & 26.003 \\
#  4735.0 &  6340.2 & 28.968 & 27.650 \\
#  6218.8 &  8453.8 & 34.474 & 36.639 \\
#  8717.1 & 11582.7 & 42.406 & 48.055 \\
# 11306.5 & 13271.0 & 49.173 & 50.628 \\
# 11262.8 & 11775.6 & 47.408 & 47.039 \\
# 12318.9 & 15266.9 & 50.514 & 56.619 \\
# 12875.1 & 14304.7 & 51.094 & 53.010 \\
# 12953.1 & 15261.4 & 52.114 & 55.291 \\
# 15931.7 & 20278.7 & 63.672 & 68.472 \\
# 20096.0 & 23795.5 & 72.794 & 78.632 \\
# 12467.0 & 16336.3 & 52.069 & 59.184 \\
#  9368.6 & 12395.9 & 45.023 & 52.294 \\
#  7134.3 &  8168.6 & 37.626 & 37.616 \\
#  6281.7 &  4221.3 & 36.520 & 25.636 \\
#  1636.4 &  2068.8 & 17.319 & 14.264 \\
#  1677.9 &  1665.3 & 19.107 & 14.185 \\
# \bottomrule
# \end{tabular}

# %%
df_mse.to_csv('../errors/errori_GConvGRU.csv', index=False)

# %%
#unisco train e test
outputs_merged = [l1 + l2 for l1, l2 in zip(outputs_hourly, outputs_hourly_test)]
targets_merged = [l1 + l2 for l1, l2 in zip(targets_hourly, targets_hourly_test)]

# %%
list_ids = loader._node_ids
dict = list_ids.item()
inverse_dict = {value: key for key, value in dict.items()}
inverse_dict.get(0)
# Out:
# '00:00'

# %%
fig, axs = plt.subplots(6, 4, figsize=(13, 10), sharey=True, sharex=True)

# Iteriamo sulla lista delle matrici e le visualizziamo in subplots
for i in range(6):
    axs[i,0].plot(targets_merged[i*4], label="Target")
    axs[i,0].plot(outputs_merged[i*4], label=name_model)
    axs[i,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,1].plot(targets_merged[i*4+1], label="Target")
    axs[i,1].plot(outputs_merged[i*4+1], label=name_model)
    axs[i,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,2].plot(targets_merged[i*4+2], label="Target")
    axs[i,2].plot(outputs_merged[i*4+2], label=name_model)
    axs[i,2].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,3].plot(targets_merged[i*4+3], label="Target")
    axs[i,3].plot(outputs_merged[i*4+3], label=name_model)
    axs[i,3].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,0].set_title(inverse_dict[i*4])  # Titolo del subplot
    axs[i,1].set_title(inverse_dict[i*4+1])
    axs[i,2].set_title(inverse_dict[i*4+2])
    axs[i,3].set_title(inverse_dict[i*4+3])
    #axs[i].axis('off')  # Nasconde gli assi

plt.legend()
plt.savefig('../plot/dyn'+name_model.lower()+'.jpg', format='jpg')
# Mostriamo la figura con tutti i subplot
plt.show()

# %%
hour = 3

diff = [a - b for a, b in zip(targets_merged[j], outputs_merged[j])]
fig, axs = plt.subplots(2, 1, figsize=(9, 8))
axs[0].plot(targets_merged[hour], label="Ground Truth")
axs[0].plot(outputs_merged[hour], label=name_model)
axs[0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0].legend()
axs[0].set_title("Daily series at "+inverse_dict[hour])
axs[1].plot(diff, label="Residual")
axs[1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1].legend()
axs[1].set_title("Residuals")
plt.show()

# %%
hour = 3

diff = [a - b for a, b in zip(targets_hourly_test[j], outputs_hourly_test[j])]
fig, axs = plt.subplots(2, 1, figsize=(9, 8))
axs[0].plot(targets_hourly_test[hour][:1000], label="Ground Truth")
axs[0].plot(outputs_hourly_test[hour][:1000], label=name_model)
axs[0].legend()
axs[0].set_title("Daily series at "+inverse_dict[hour]+" in the test set")
axs[1].plot(diff[:1000], label="Residual")
axs[1].legend()
axs[1].set_title("Residuals")
plt.show()

# %%
hour1 = 4
hour2 = 16

diff1 = [a - b for a, b in zip(targets_merged[hour1], outputs_merged[hour1])]
diff2 = [a - b for a, b in zip(targets_merged[hour2], outputs_merged[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_merged[hour1], label="Ground Truth")
axs[0,0].plot(outputs_merged[hour1], label=name_model)
axs[0,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0,0].legend()
axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1])
axs[1,0].plot(diff1, label="Residual")
axs[1,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1,0].legend()
axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_merged[hour2], label="Ground Truth")
axs[0,1].plot(outputs_merged[hour2], label=name_model)
axs[0,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0,1].legend()
axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2])
axs[1,1].plot(diff2, label="Residual")
axs[1,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1,1].legend()
axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('plot/focusdyn'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
hour1 = 2
hour2 = 16
id=1000
fd=1150

diff1 = [a - b for a, b in zip(targets_hourly_test[hour1], outputs_hourly_test[hour1])]
diff2 = [a - b for a, b in zip(targets_hourly_test[hour2], outputs_hourly_test[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_hourly_test[hour1][id:fd], label="Ground Truth")
axs[0,0].plot(outputs_hourly_test[hour1][id:fd], label=name_model)
axs[0,0].legend()
#axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1]+" in first "+str(fd-id)+" days of the test set")
axs[1,0].plot(diff1[id:fd], label="Residual")
axs[1,0].legend()
#axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_hourly_test[hour2][id:fd], label="Ground Truth")
axs[0,1].plot(outputs_hourly_test[hour2][id:fd], label=name_model)
axs[0,1].legend()
#axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2]+" in first "+str(fd-id)+" days of the test set")
axs[1,1].plot(diff2[id:fd], label="Residual")
axs[1,1].legend()
#axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('../plot/focustestdyn'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
##############

##############

##############
import pandas as pd
data_vec = pd.read_csv('errors/vec.csv')
data_vec
# Out:
#                x
# 0      55.475638
# 1      63.745574
# 2      52.759182
# 3      71.888373
# 4      80.559589
# ...          ...
# 7929  400.844548
# 7930  909.544470
# 7931  508.964608
# 7932  205.607561
# 7933  170.320681
#
# [7934 rows x 1 columns]

# %%
hour1 = 2
hour2 = 16
id=140
#id=100
#id=1220
fd=id+150
train_size=6346
vec = data_vec.iloc[train_size+id:train_size+fd,0].to_list()
#vec

# %%
np.mean([(a - b)**2 for a, b in zip(targets_hourly_test[hour2][id:fd],vec)])
# Out:
# 17503.044466971365

# %%
np.mean([(a - b)**2 for a, b in zip(targets_hourly_test[hour2][id:fd],outputs_hourly_test[hour2][id:fd])])
# Out:
# 23244.392921525472

# %%
np.mean([abs(a - b) for a, b in zip(targets_hourly_test[hour2][id:fd],vec)])
# Out:
# 49.460019682978746

# %%
np.mean([abs(a - b) for a, b in zip(targets_hourly_test[hour2][id:fd],outputs_hourly_test[hour2][id:fd])])
# Out:
# 52.734332583079635

# %%
diff1 = [a - b for a, b in zip(targets_hourly_test[hour1], outputs_hourly_test[hour1])]
diff2 = [a - b for a, b in zip(targets_hourly_test[hour2], outputs_hourly_test[hour2])]
fig, axs = plt.subplots(2, 1, figsize=(16, 7))
axs[0].plot(targets_hourly_test[hour2][id:fd], label="Ground Truth")
axs[0].plot(outputs_hourly_test[hour2][id:fd], label=name_model)
axs[0].plot(vec, label='VAR')
axs[0].legend()
#axs[0,1].set_ylim(-40,1040)
axs[1].set_title("Daily series at "+inverse_dict[hour2]+" in first "+str(fd)+" days of the test set")
axs[1].plot(diff2[id:fd], label="Residual GConv")
axs[1].plot([a - b for a, b in zip(targets_hourly_test[hour2][id:fd],vec)], label='VAR')
axs[1].legend()
#axs[1,1].set_ylim(-1040,1040)
axs[1].set_title("Residuals")
plt.show()

# %%
#o uno o l'altro
hour1 = 4
hour2 = 16
fd=100

diff1 = [a - b for a, b in zip(targets_hourly_test[hour1], outputs_hourly_test[hour1])]
diff2 = [a - b for a, b in zip(targets_hourly_test[hour2], outputs_hourly_test[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_hourly_test[hour1][-fd:], label="Ground Truth")
axs[0,0].plot(outputs_hourly_test[hour1][-fd:], label=name_model)
axs[0,0].legend()
#axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1]+" in last "+str(fd)+" days of the test set")
axs[1,0].plot(diff1[-fd:], label="Residual")
axs[1,0].legend()
#axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_hourly_test[hour2][-fd:], label="Ground Truth")
axs[0,1].plot(outputs_hourly_test[hour2][-fd:], label=name_model)
axs[0,1].legend()
#axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2]+" in last "+str(fd)+" days of the test set")
axs[1,1].plot(diff2[-fd:], label="Residual")
axs[1,1].legend()
#axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('../plot/focustestdyn'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
df_compare = pd.DataFrame({'a': outputs_hourly_test[hour1][-fd:], 'b': outputs_hourly_test[hour2][-fd:], 'c': diff1[-fd:], 'd': diff2[-fd:]})

# %%
# df_compare.to_csv('plot/compare/compare_gconv.csv', index=False)

# %%
# #Per salvare modello
# model = model.to('cpu')
# torch.save(model.state_dict(), '../models/gnn_dyn'+name_model+'_3_10_3_3_relu_0.01.pth')

# %%
# Per caricare modello
model = GNN(node_features = lags)
model.load_state_dict(torch.load('../models/gnn_dyn'+name_model+'_3_10_3_3_relu_0.01.pth'))
#model = model.to('cuda')
print(model)
# Out:
# GNN(
#   (recurrent): GConvGRU_W(
#     (conv_x_z): ChebConv_w(3, 10, K=3, normalization=sym)
#     (conv_q_z): ChebConv_w(10, 10, K=3, normalization=sym)
#     (conv_x_r): ChebConv_w(3, 10, K=3, normalization=sym)
#     (conv_q_r): ChebConv_w(10, 10, K=3, normalization=sym)
#     (conv_x_h): ChebConv_w(3, 10, K=3, normalization=sym)
#     (conv_q_h): ChebConv_w(10, 10, K=3, normalization=sym)
#   )
#   (linear): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
#Training set
H = torch.zeros(24,out_channels)
outputs = []  #
targets = []  #
for time_step, snapshot in enumerate(train_dataset):
    #snapshot.to('cuda')
    output, H = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr, H=H)
    train_output = descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale)
    train_snapshot = descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale)
    outputs.append(train_output)  #
    targets.append(train_snapshot)   #

# %%
outputs_hourly = []
targets_hourly = []
for j in range(24):
    outhourlist = [outputs[i][j] for i in range(len(outputs))]
    tarhourlist = [targets[i][j] for i in range(len(outputs))]
    outputs_hourly.append(outhourlist)
    targets_hourly.append(tarhourlist)
