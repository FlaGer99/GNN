# %%
import json
import numpy as np
from torch_geometric_temporal.signal import DynamicGraphTemporalSignal
import torch
import time


class MyDynamicDatasetLoader(object):
    def __init__(self):
        self._read_web_data()

    def _read_web_data(self):
        with open('data/graphs/grafo_corr_sliding.json') as f:
            self._dataset = json.load(f)

    def _get_edges(self):
        self._edges = []
        for time in self._dataset["time_periods"]:
            self._edges.append(
                np.array(self._dataset["edge_mapping"]["edge_index"][str(time)]).T
            )
        self._edges = self._edges[self.lags-1:]

    def _get_node_ids(self):
        self._node_ids = np.array(self._dataset["node_ids"])
    
    def _get_edge_weights(self):
        self._edge_weights = []
        for time in self._dataset["time_periods"]:
            self._edge_weights.append(
                np.array(self._dataset["edge_mapping"]["edge_weight"][str(time)])
            )
        self._edge_weights = self._edge_weights[self.lags-1:]

    def _get_targets_and_features(self):
        stacked_target = np.array(self._dataset["y"])
        self.scale = []
        for i in range(24):
            self.scale.append(max(stacked_target[:,i]))
        self.scale = np.array(self.scale)
        self.mu = np.mean(stacked_target, axis=0)
        self.sigma = np.std(stacked_target, axis=0)
        #standardized_target = (stacked_target - self.mu) / (self.sigma + 10 ** -10)
        standardized_target = stacked_target/self.scale
        self.features = [
            standardized_target[i : i + self.lags, :].T
            for i in range(len(self._dataset["time_periods"])-self.lags+1)
        ]
        self.targets = [
            standardized_target[i + self.lags, :].T
            for i in range(len(self._dataset["time_periods"])-self.lags+1)
        ]

    def get_dataset(self, lags: int = 4) -> DynamicGraphTemporalSignal:
        """Returning the Wind Speed data iterator.

        Args types:
            * **lags** *(int)* - The number of time lags.
        Return types:
            * **dataset** *(StaticGraphTemporalSignal)* - The Wind Speed dataset.
        """
        self.lags = lags
        self._get_edges()
        self._get_edge_weights()
        self._get_node_ids()
        self._get_targets_and_features()
        dataset = DynamicGraphTemporalSignal(
            self._edges, self._edge_weights, self.features, self.targets
        )
        return dataset

# %%
lags = 3
out_channels1 = 10
out_channels2 = 20
loader = MyDynamicDatasetLoader()
dataset = loader.get_dataset(lags=lags)
dataset[1]
# Out:
# Data(x=[24, 3], edge_index=[2, 342], edge_attr=[342], y=[24])

# %%
import torch.nn.functional as F
from matplotlib import pyplot as plt
from torch_geometric_temporal.nn.recurrent import GConvGRU, TGCN, GConvLSTM
from torch_geometric_temporal.signal import temporal_signal_split

train_dataset, test_dataset = temporal_signal_split(dataset, train_ratio=0.8)

# %%
class RecurrentGCN(torch.nn.Module):
    def __init__(self, node_features):
        super(RecurrentGCN, self).__init__()
        self.recurrent1 = TGCN(in_channels=node_features, out_channels=out_channels1, add_self_loops=False)
        self.recurrent2 = TGCN(in_channels=out_channels1, out_channels=out_channels2, add_self_loops=False)
        self.linear1 = torch.nn.Linear(out_channels2, 10)
        self.linear2 = torch.nn.Linear(10,1)
        self.dropout1 = torch.nn.Dropout(0.4)

    def forward(self, x, edge_index, edge_weight, H1, H2):
        H1 = self.recurrent1(x, edge_index, edge_weight, H1)
        H1 = self.dropout1(H1)
        H2 = self.recurrent2(H1, edge_index, edge_weight, H2)
        h = H2
        #h = self.dropout1(h)
        h = F.relu(h)
        h = self.linear1(h)
        h = F.relu(h)
        h = self.linear2(h)
        return h,H1,H2

# %%
model = RecurrentGCN(node_features = lags)
name_model = model.recurrent1.__class__.__name__
name_model
# Out:
# 'TGCN'

# %%
sigma = loader.sigma
mu = loader.mu
scale = loader.scale
def descale(output, sigma, mu, scale):
    return output*scale#sigma + mu

# %%
#model = model.to('cuda')
model.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.017, weight_decay=0.05)
loss_fn = F.mse_loss

start_time = time.perf_counter() # Start timer
num_epochs = 250
losses = []
outputs = []  #
targets = []  #
for epoch in range(num_epochs):
    loss = 0
    epoch_outputs = []  #
    epoch_targets = []  #
    H1 = torch.zeros(24,out_channels1)
    H2 = torch.zeros(24,out_channels2)
    print("  Epoch %d/%d" % (epoch+1,num_epochs))
    for time_step, snapshot in enumerate(train_dataset):
        #snapshot.to('cuda')
        output, H1, H2 = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr, H1=H1, H2=H2)
        loss = loss + loss_fn(output.T[0], snapshot.y)
        epoch_outputs.append(descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale))  #
        epoch_targets.append(descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale))   #

    loss = loss/(time_step+1)
    
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    losses.append(loss.cpu().detach().numpy())
    outputs.append(epoch_outputs)  #
    targets.append(epoch_targets)  #
    print('Training loss: ', losses[-1])

end_time = time.perf_counter() # End timer
print("Elapsed time: ", end_time - start_time) # Calculate elapsed time

plt.plot(losses)
plt.xlabel("epoch")
# Out:
#   Epoch 1/250
# Training loss:  0.07946441
#   Epoch 2/250
# Training loss:  0.05763302
#   Epoch 3/250
# Training loss:  0.04023179
#   Epoch 4/250
# Training loss:  0.026860064
#   Epoch 5/250
# Training loss:  0.017663898
#   Epoch 6/250
# Training loss:  0.012915901
#   Epoch 7/250
# Training loss:  0.012107302
#   Epoch 8/250
# Training loss:  0.0133260675
#   Epoch 9/250
# Training loss:  0.014338225
#   Epoch 10/250
# Training loss:  0.014270382
#   Epoch 11/250
# Training loss:  0.013499741
#   Epoch 12/250
# Training loss:  0.012662947
#   Epoch 13/250
# Training loss:  0.0121670365
#   Epoch 14/250
# Training loss:  0.012072292
#   Epoch 15/250
# Training loss:  0.012221374
#   Epoch 16/250
# Training loss:  0.012403421
#   Epoch 17/250
# Training loss:  0.012517932
#   Epoch 18/250
# Training loss:  0.012555052
#   Epoch 19/250
# Training loss:  0.012537275
#   Epoch 20/250
# Training loss:  0.012488878
#   Epoch 21/250
# Training loss:  0.012434226
#   Epoch 22/250
# Training loss:  0.012386333
#   Epoch 23/250
# Training loss:  0.012337004
#   Epoch 24/250
# Training loss:  0.012291607
#   Epoch 25/250
# Training loss:  0.012253499
#   Epoch 26/250
# Training loss:  0.012223947
#   Epoch 27/250
# Training loss:  0.012201568
#   Epoch 28/250
# Training loss:  0.012185099
#   Epoch 29/250
# Training loss:  0.012173872
#   Epoch 30/250
# Training loss:  0.012166705
#   Epoch 31/250
# Training loss:  0.01216265
#   Epoch 32/250
# Training loss:  0.01216099
#   Epoch 33/250
# Training loss:  0.012162913
#   Epoch 34/250
# Training loss:  0.01216622
#   Epoch 35/250
# Training loss:  0.012169009
#   Epoch 36/250
# Training loss:  0.012170714
#   Epoch 37/250
# Training loss:  0.012171249
#   Epoch 38/250
# Training loss:  0.012170024
#   Epoch 39/250
# Training loss:  0.012165705
#   Epoch 40/250
# Training loss:  0.012159167
#   Epoch 41/250
# Training loss:  0.01215213
#   Epoch 42/250
# Training loss:  0.012144603
#   Epoch 43/250
# Training loss:  0.01213657
#   Epoch 44/250
# Training loss:  0.012127897
#   Epoch 45/250
# Training loss:  0.012118693
#   Epoch 46/250
# Training loss:  0.012109103
#   Epoch 47/250
# Training loss:  0.0120995445
#   Epoch 48/250
# Training loss:  0.012090454
#   Epoch 49/250
# Training loss:  0.012082171
#   Epoch 50/250
# Training loss:  0.01207504
#   Epoch 51/250
# Training loss:  0.012069386
#   Epoch 52/250
# Training loss:  0.012065164
#   Epoch 53/250
# Training loss:  0.012062285
#   Epoch 54/250
# Training loss:  0.012060528
#   Epoch 55/250
# Training loss:  0.012059476
#   Epoch 56/250
# Training loss:  0.01205892
#   Epoch 57/250
# Training loss:  0.012058685
#   Epoch 58/250
# Training loss:  0.0120585775
#   Epoch 59/250
# Training loss:  0.012058539
#   Epoch 60/250
# Training loss:  0.012058561
#   Epoch 61/250
# Training loss:  0.012058573
#   Epoch 62/250
# Training loss:  0.012058605
#   Epoch 63/250
# Training loss:  0.012058663
#   Epoch 64/250
# Training loss:  0.012058775
#   Epoch 65/250
# Training loss:  0.012058904
#   Epoch 66/250
# Training loss:  0.012059086
#   Epoch 67/250
# Training loss:  0.012059277
#   Epoch 68/250
# Training loss:  0.012059538
#   Epoch 69/250
# Training loss:  0.012059715
#   Epoch 70/250
# Training loss:  0.012059904
#   Epoch 71/250
# Training loss:  0.012060094
#   Epoch 72/250
# Training loss:  0.012060233
#   Epoch 73/250
# Training loss:  0.01206038
#   Epoch 74/250
# Training loss:  0.012060462
#   Epoch 75/250
# Training loss:  0.012060594
#   Epoch 76/250
# Training loss:  0.012060642
#   Epoch 77/250
# Training loss:  0.012060719
#   Epoch 78/250
# Training loss:  0.01206078
#   Epoch 79/250
# Training loss:  0.012060862
#   Epoch 80/250
# Training loss:  0.012060926
#   Epoch 81/250
# Training loss:  0.012060962
#   Epoch 82/250
# Training loss:  0.012061012
#   Epoch 83/250
# Training loss:  0.012061063
#   Epoch 84/250
# Training loss:  0.012061084
#   Epoch 85/250
# Training loss:  0.01206109
#   Epoch 86/250
# Training loss:  0.012061102
#   Epoch 87/250
# Training loss:  0.012061102
#   Epoch 88/250
# Training loss:  0.012061099
#   Epoch 89/250
# Training loss:  0.012061094
#   Epoch 90/250
# Training loss:  0.01206109
#   Epoch 91/250
# Training loss:  0.012061087
#   Epoch 92/250
# Training loss:  0.012061094
#   Epoch 93/250
# Training loss:  0.0120610995
#   Epoch 94/250
# Training loss:  0.0120611
#   Epoch 95/250
# Training loss:  0.012061097
#   Epoch 96/250
# Training loss:  0.012061126
#   Epoch 97/250
# Training loss:  0.0120611545
#   Epoch 98/250
# Training loss:  0.01206118
#   Epoch 99/250
# Training loss:  0.012061202
#   Epoch 100/250
# Training loss:  0.01206122
#   Epoch 101/250
# Training loss:  0.012061221
#   Epoch 102/250
# Training loss:  0.012061227
#   Epoch 103/250
# Training loss:  0.012061228
#   Epoch 104/250
# Training loss:  0.012061229
#   Epoch 105/250
# Training loss:  0.012061225
#   Epoch 106/250
# Training loss:  0.012061216
#   Epoch 107/250
# Training loss:  0.012061214
#   Epoch 108/250
# Training loss:  0.012061206
#   Epoch 109/250
# Training loss:  0.012061189
#   Epoch 110/250
# Training loss:  0.012061182
#   Epoch 111/250
# Training loss:  0.012061175
#   Epoch 112/250
# Training loss:  0.012061153
#   Epoch 113/250
# Training loss:  0.012061134
#   Epoch 114/250
# Training loss:  0.012061125
#   Epoch 115/250
# Training loss:  0.012061121
#   Epoch 116/250
# Training loss:  0.012061116
#   Epoch 117/250
# Training loss:  0.012061124
#   Epoch 118/250
# Training loss:  0.012061124
#   Epoch 119/250
# Training loss:  0.012061117
#   Epoch 120/250
# Training loss:  0.012061121
#   Epoch 121/250
# Training loss:  0.012061123
#   Epoch 122/250
# Training loss:  0.012061128
#   Epoch 123/250
# Training loss:  0.012061133
#   Epoch 124/250
# Training loss:  0.012061142
#   Epoch 125/250
# Training loss:  0.012061153
#   Epoch 126/250
# Training loss:  0.012061158
#   Epoch 127/250
# Training loss:  0.012061171
#   Epoch 128/250
# Training loss:  0.012061182
#   Epoch 129/250
# Training loss:  0.012061179
#   Epoch 130/250
# Training loss:  0.0120611815
#   Epoch 131/250
# Training loss:  0.012061182
#   Epoch 132/250
# Training loss:  0.0120611815
#   Epoch 133/250
# Training loss:  0.012061182
#   Epoch 134/250
# Training loss:  0.0120611815
#   Epoch 135/250
# Training loss:  0.012061185
#   Epoch 136/250
# Training loss:  0.012061174
#   Epoch 137/250
# Training loss:  0.01206118
#   Epoch 138/250
# Training loss:  0.012061185
#   Epoch 139/250
# Training loss:  0.012061175
#   Epoch 140/250
# Training loss:  0.01206117
#   Epoch 141/250
# Training loss:  0.012061162
#   Epoch 142/250
# Training loss:  0.012061161
#   Epoch 143/250
# Training loss:  0.012061162
#   Epoch 144/250
# Training loss:  0.012061157
#   Epoch 145/250
# Training loss:  0.0120611545
#   Epoch 146/250
# Training loss:  0.012061154
#   Epoch 147/250
# Training loss:  0.012061154
#   Epoch 148/250
# Training loss:  0.012061153
#   Epoch 149/250
# Training loss:  0.012061153
#   Epoch 150/250
# Training loss:  0.012061162
#   Epoch 151/250
# Training loss:  0.012061161
#   Epoch 152/250
# Training loss:  0.012061161
#   Epoch 153/250
# Training loss:  0.012061163
#   Epoch 154/250
# Training loss:  0.012061156
#   Epoch 155/250
# Training loss:  0.01206116
#   Epoch 156/250
# Training loss:  0.012061169
#   Epoch 157/250
# Training loss:  0.012061169
#   Epoch 158/250
# Training loss:  0.012061173
#   Epoch 159/250
# Training loss:  0.012061173
#   Epoch 160/250
# Training loss:  0.012061173
#   Epoch 161/250
# Training loss:  0.012061173
#   Epoch 162/250
# Training loss:  0.012061171
#   Epoch 163/250
# Training loss:  0.012061173
#   Epoch 164/250
# Training loss:  0.012061171
#   Epoch 165/250
# Training loss:  0.01206117
#   Epoch 166/250
# Training loss:  0.012061169
#   Epoch 167/250
# Training loss:  0.012061169
#   Epoch 168/250
# Training loss:  0.012061163
#   Epoch 169/250
# Training loss:  0.012061161
#   Epoch 170/250
# Training loss:  0.012061157
#   Epoch 171/250
# Training loss:  0.012061157
#   Epoch 172/250
# Training loss:  0.01206116
#   Epoch 173/250
# Training loss:  0.01206116
#   Epoch 174/250
# Training loss:  0.012061161
#   Epoch 175/250
# Training loss:  0.01206116
#   Epoch 176/250
# Training loss:  0.012061158
#   Epoch 177/250
# Training loss:  0.012061158
#   Epoch 178/250
# Training loss:  0.012061156
#   Epoch 179/250
# Training loss:  0.012061156
#   Epoch 180/250
# Training loss:  0.012061158
#   Epoch 181/250
# Training loss:  0.01206116
#   Epoch 182/250
# Training loss:  0.012061162
#   Epoch 183/250
# Training loss:  0.012061163
#   Epoch 184/250
# Training loss:  0.012061162
#   Epoch 185/250
# Training loss:  0.012061165
#   Epoch 186/250
# Training loss:  0.012061167
#   Epoch 187/250
# Training loss:  0.012061169
#   Epoch 188/250
# Training loss:  0.012061169
#   Epoch 189/250
# Training loss:  0.012061167
#   Epoch 190/250
# Training loss:  0.012061167
#   Epoch 191/250
# Training loss:  0.012061163
#   Epoch 192/250
# Training loss:  0.012061162
#   Epoch 193/250
# Training loss:  0.012061161
#   Epoch 194/250
# Training loss:  0.012061161
#   Epoch 195/250
# Training loss:  0.012061161
#   Epoch 196/250
# Training loss:  0.012061161
#   Epoch 197/250
# Training loss:  0.01206116
#   Epoch 198/250
# Training loss:  0.01206116
#   Epoch 199/250
# Training loss:  0.012061161
#   Epoch 200/250
# Training loss:  0.01206116
#   Epoch 201/250
# Training loss:  0.01206116
#   Epoch 202/250
# Training loss:  0.012061161
#   Epoch 203/250
# Training loss:  0.01206116
#   Epoch 204/250
# Training loss:  0.01206116
#   Epoch 205/250
# Training loss:  0.012061161
#   Epoch 206/250
# Training loss:  0.012061161
#   Epoch 207/250
# Training loss:  0.012061162
#   Epoch 208/250
# Training loss:  0.012061162
#   Epoch 209/250
# Training loss:  0.012061161
#   Epoch 210/250
# Training loss:  0.012061161
#   Epoch 211/250
# Training loss:  0.012061161
#   Epoch 212/250
# Training loss:  0.012061161
#   Epoch 213/250
# Training loss:  0.012061161
#   Epoch 214/250
# Training loss:  0.012061161
#   Epoch 215/250
# Training loss:  0.012061161
#   Epoch 216/250
# Training loss:  0.012061161
#   Epoch 217/250
# Training loss:  0.012061161
#   Epoch 218/250
# Training loss:  0.012061161
#   Epoch 219/250
# Training loss:  0.012061162
#   Epoch 220/250
# Training loss:  0.012061162
#   Epoch 221/250
# Training loss:  0.012061161
#   Epoch 222/250
# Training loss:  0.01206116
#   Epoch 223/250
# Training loss:  0.012061161
#   Epoch 224/250
# Training loss:  0.012061161
#   Epoch 225/250
# Training loss:  0.012061161
#   Epoch 226/250
# Training loss:  0.012061161
#   Epoch 227/250
# Training loss:  0.012061161
#   Epoch 228/250
# Training loss:  0.012061161
#   Epoch 229/250
# Training loss:  0.01206116
#   Epoch 230/250
# Training loss:  0.01206116
#   Epoch 231/250
# Training loss:  0.012061161
#   Epoch 232/250
# Training loss:  0.012061162
#   Epoch 233/250
# Training loss:  0.012061162
#   Epoch 234/250
# Training loss:  0.012061162
#   Epoch 235/250
# Training loss:  0.012061162
#   Epoch 236/250
# Training loss:  0.012061162
#   Epoch 237/250
# Training loss:  0.012061162
#   Epoch 238/250
# Training loss:  0.012061162
#   Epoch 239/250
# Training loss:  0.012061162
#   Epoch 240/250
# Training loss:  0.012061162
#   Epoch 241/250
# Training loss:  0.012061162
#   Epoch 242/250
# Training loss:  0.012061162
#   Epoch 243/250
# Training loss:  0.012061162
#   Epoch 244/250
# Training loss:  0.012061162
#   Epoch 245/250
# Training loss:  0.012061161
#   Epoch 246/250
# Training loss:  0.012061161
#   Epoch 247/250
# Training loss:  0.012061161
#   Epoch 248/250
# Training loss:  0.012061161
#   Epoch 249/250
# Training loss:  0.012061161
#   Epoch 250/250
# Training loss:  0.012061161
# Elapsed time:  1798.8924660229986
# Text(0.5, 0, 'epoch')

# %%
#plt.plot(losses)

# %%
# a=model(snapshot.x, snapshot.edge_index, snapshot.edge_attr)
# print(a)

# %%
# print(epoch_outputs.append(descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale)))
# print(epoch_targets.append(descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale)))

# %%
outputs_hourly = []
targets_hourly = []
for j in range(24):
    outhourlist = [outputs[-1][i][j] for i in range(len(outputs[-1]))]
    tarhourlist = [targets[-1][i][j] for i in range(len(outputs[-1]))]
    outputs_hourly.append(outhourlist)
    targets_hourly.append(tarhourlist)

# %%
#Test set
test_outputs = []  #
test_targets = []  #
for time_step, snapshot in enumerate(test_dataset):
    #snapshot.to('cuda')
    output, H1, H2 = model(snapshot.x, snapshot.edge_index, snapshot.edge_attr, H1=H1, H2=H2)
    test_output = descale(output.T[0].detach().cpu().numpy(), sigma, mu, scale)
    test_snapshot = descale(snapshot.y.detach().cpu().numpy(), sigma, mu, scale)
    test_outputs.append(test_output)  #
    test_targets.append(test_snapshot)   #
#snapshot.x

# %%
outputs_hourly_test = []
targets_hourly_test = []
for j in range(24):
    outhourlist = [test_outputs[i][j] for i in range(len(test_outputs))]
    tarhourlist = [test_targets[i][j] for i in range(len(test_outputs))]
    outputs_hourly_test.append(outhourlist)
    targets_hourly_test.append(tarhourlist)

# %%
mse_test = []
for j in range(24):
    sqdiff = [(a - b)**2 for a, b in zip(targets_hourly_test[j], outputs_hourly_test[j])]
    mse_test.append(np.mean(sqdiff))
mse_test
# Out:
# [1890.1386383860126,
#  817.0802549648495,
#  411.20496052733296,
#  639.3052191716542,
#  821.7279333028754,
#  1647.1709114689684,
#  4951.996544901227,
#  7134.3385539105475,
#  8263.562234418234,
#  10743.544207495257,
#  14322.573977694516,
#  15884.562605313828,
#  14086.144366859853,
#  17931.623900209932,
#  18248.822996911815,
#  19710.126908413255,
#  27432.617979745,
#  31889.82628776017,
#  21794.592072100004,
#  15345.04365036136,
#  9224.758391127207,
#  4544.4031101603905,
#  2752.6150597680844,
#  2484.915362743395]

# %%
np.mean(mse_test)
# Out:
# 10540.52900532149

# %%
mse_train = []
for j in range(24):
    sqdiff = [(a - b)**2 for a, b in zip(targets_hourly[j], outputs_hourly[j])]
    mse_train.append(np.mean(sqdiff))
mse_train
# Out:
# [2184.948051535189,
#  1262.767070870074,
#  621.9736145512709,
#  802.5280714396197,
#  1004.7714367077951,
#  1381.7519729159362,
#  4517.589344629845,
#  5653.239535678248,
#  7427.802228354196,
#  9760.975685397641,
#  14576.692693017449,
#  19752.299358125485,
#  19743.845327794563,
#  21664.821767915742,
#  22617.35861693403,
#  23091.327328241663,
#  27806.107840586712,
#  36012.607164013876,
#  20633.355605914345,
#  15144.741948669538,
#  11588.865876639302,
#  9859.572359031115,
#  3153.4912760461034,
#  2821.5703230012523]

# %%
np.mean(mse_train)
# Out:
# 11795.208520750459

# %%
#unisco train e test
outputs_merged = [l1 + l2 for l1, l2 in zip(outputs_hourly, outputs_hourly_test)]
targets_merged = [l1 + l2 for l1, l2 in zip(targets_hourly, targets_hourly_test)]

# %%
list_ids = loader._node_ids
dict = list_ids.item()
inverse_dict = {value: key for key, value in dict.items()}
inverse_dict.get(0)
# Out:
# '00:00'

# %%
fig, axs = plt.subplots(6, 4, figsize=(11, 10), sharey=True, sharex=True)

# Iteriamo sulla lista delle matrici e le visualizziamo in subplots
for i in range(6):
    axs[i,0].plot(targets_merged[i*4], label="Target")
    axs[i,0].plot(outputs_merged[i*4], label=name_model)
    axs[i,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,1].plot(targets_merged[i*4+1], label="Target")
    axs[i,1].plot(outputs_merged[i*4+1], label=name_model)
    axs[i,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,2].plot(targets_merged[i*4+2], label="Target")
    axs[i,2].plot(outputs_merged[i*4+2], label=name_model)
    axs[i,2].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,3].plot(targets_merged[i*4+3], label="Target")
    axs[i,3].plot(outputs_merged[i*4+3], label=name_model)
    axs[i,3].axvline(x=6420, color='black', linestyle='--', linewidth=1)
    axs[i,0].set_title(inverse_dict[i*4])  # Titolo del subplot
    axs[i,1].set_title(inverse_dict[i*4+1])
    axs[i,2].set_title(inverse_dict[i*4+2])
    axs[i,3].set_title(inverse_dict[i*4+3])
    #axs[i].axis('off')  # Nasconde gli assi

plt.legend()
plt.savefig('plot/dyn'+name_model.lower()+'.jpg', format='jpg')
# Mostriamo la figura con tutti i subplot
plt.show()

# %%
hour = 3

diff = [a - b for a, b in zip(targets_merged[j], outputs_merged[j])]
fig, axs = plt.subplots(2, 1, figsize=(9, 8))
axs[0].plot(targets_merged[hour], label="Ground Truth")
axs[0].plot(outputs_merged[hour], label=name_model)
axs[0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0].legend()
axs[0].set_title("Daily series at "+inverse_dict[hour])
axs[1].plot(diff, label="Residual")
axs[1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1].legend()
axs[1].set_title("Residuals")
plt.show()

# %%
hour = 3

diff = [a - b for a, b in zip(targets_hourly_test[j], outputs_hourly_test[j])]
fig, axs = plt.subplots(2, 1, figsize=(9, 8))
axs[0].plot(targets_hourly_test[hour][:1000], label="Ground Truth")
axs[0].plot(outputs_hourly_test[hour][:1000], label=name_model)
axs[0].legend()
axs[0].set_title("Daily series at "+inverse_dict[hour]+" in the test set")
axs[1].plot(diff[:1000], label="Residual")
axs[1].legend()
axs[1].set_title("Residuals")
plt.show()

# %%
hour1 = 2
hour2 = 16

diff1 = [a - b for a, b in zip(targets_merged[hour1], outputs_merged[hour1])]
diff2 = [a - b for a, b in zip(targets_merged[hour2], outputs_merged[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_merged[hour1], label="Ground Truth")
axs[0,0].plot(outputs_merged[hour1], label=name_model)
axs[0,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0,0].legend()
axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1])
axs[1,0].plot(diff1, label="Residual")
axs[1,0].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1,0].legend()
axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_merged[hour2], label="Ground Truth")
axs[0,1].plot(outputs_merged[hour2], label=name_model)
axs[0,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[0,1].legend()
axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2])
axs[1,1].plot(diff2, label="Residual")
axs[1,1].axvline(x=6420, color='black', linestyle='--', linewidth=1)
axs[1,1].legend()
axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('plot/focusdyn'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
hour1 = 2
hour2 = 16
fd=200

diff1 = [a - b for a, b in zip(targets_hourly_test[hour1], outputs_hourly_test[hour1])]
diff2 = [a - b for a, b in zip(targets_hourly_test[hour2], outputs_hourly_test[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_hourly_test[hour1][:fd], label="Ground Truth")
axs[0,0].plot(outputs_hourly_test[hour1][:fd], label=name_model)
axs[0,0].legend()
#axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1]+" in first "+str(fd)+" days of the test set")
axs[1,0].plot(diff1[:fd], label="Residual")
axs[1,0].legend()
#axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_hourly_test[hour2][:fd], label="Ground Truth")
axs[0,1].plot(outputs_hourly_test[hour2][:fd], label=name_model)
axs[0,1].legend()
#axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2]+" in first "+str(fd)+" days of the test set")
axs[1,1].plot(diff2[:fd], label="Residual")
axs[1,1].legend()
#axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('plot/focustestdyn'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
#o uno o l'altro
hour1 = 2
hour2 = 16
fd=100

diff1 = [a - b for a, b in zip(targets_hourly_test[hour1], outputs_hourly_test[hour1])]
diff2 = [a - b for a, b in zip(targets_hourly_test[hour2], outputs_hourly_test[hour2])]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].plot(targets_hourly_test[hour1][-fd:], label="Ground Truth")
axs[0,0].plot(outputs_hourly_test[hour1][-fd:], label=name_model)
axs[0,0].legend()
#axs[0,0].set_ylim(-40,1040)
axs[0,0].set_title("Daily series at "+inverse_dict[hour1]+" in last "+str(fd)+" days of the test set")
axs[1,0].plot(diff1[-fd:], label="Residual")
axs[1,0].legend()
#axs[1,0].set_ylim(-1040,1040)
axs[1,0].set_title("Residuals")
axs[0,1].plot(targets_hourly_test[hour2][-fd:], label="Ground Truth")
axs[0,1].plot(outputs_hourly_test[hour2][-fd:], label=name_model)
axs[0,1].legend()
#axs[0,1].set_ylim(-40,1040)
axs[0,1].set_title("Daily series at "+inverse_dict[hour2]+" in last "+str(fd)+" days of the test set")
axs[1,1].plot(diff2[-fd:], label="Residual")
axs[1,1].legend()
#axs[1,1].set_ylim(-1040,1040)
axs[1,1].set_title("Residuals")
plt.savefig('plot/focustestdyn'+name_model.lower()+'.jpg', format='jpg')
plt.show()

# %%
# Per salvare modello
#model = model.to('cpu')
#torch.save(model.state_dict(), 'models/gnn_dyn2'+name_model+'_3_0.1.pth')

# %%
# Per caricare modello
#model = RecurrentGCN(node_features = lags)
#model.load_state_dict(torch.load('models/gnn_dyn2TGCN_3_0.1.pth'))
#model = model.to('cuda')
#print(model)
